# %% [markdown]
# # Number of Messages Sent Factorial Analysis (High Density Scenario)

# %%
import os
import math
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from itertools import product, chain, combinations
from scipy import stats
from IPython.display import display, HTML
# %matplotlib inline

def parse_if_number(s):
    try: return float(s)
    except: return True if s=="true" else False if s=="false" else s if s else None

def parse_ndarray(s):
    return np.fromstring(s, sep=' ') if s else None

def get_file_name(name):
    return name.replace(':', '-')

# %% [markdown]
# ## Config

# %%
inputFile = 'messages.csv'
repetitionsCount = -1 # -1 = auto-detect
factors = ['R', 'T', 'm']

tIntervalAlpha = 0.95

plotSize = (10, 10)
plotStyle = 'seaborn-whitegrid'
saveFigures = False

# Filter scalars
scalarsFilter = ['Floorplan.userCount', 'Floorplan.msgsPerSlot:sum']
# Filter vectors
vectorsFilter = []
# Percentiles
percentiles = [0.25, 0.5, 0.75, 0.9, 0.95]

# Performance indexes
perfIndexes = [
    ('Floorplan.msgsPerSlot:sum', 'total number of messages sent'),
]

# Transformations
transformations = [
]

intPercentiles = [int(i*100) for i in percentiles]
vecPerfIndexes = []
#for intPercentile in intPercentiles:
    #vecPerfIndexes.append(('broadcastTime' + str(intPercentile), 'Broadcast time needed to reach the ' + str(intPercentile) + 'th percentile of the coverage'))
for v in vecPerfIndexes:
    perfIndexes.append(v)
    #transformations.append((v[0], lambda x: math.log(x)))

# %% [markdown]
# ## Load scalars

# %%
df = pd.read_csv('exported_data/' + inputFile, converters = {
    'attrvalue': parse_if_number,
    'binedges': parse_ndarray,
    'binvalues': parse_ndarray,
    'vectime': parse_ndarray,
    'vecvalue': parse_ndarray,
})

# %%
if repetitionsCount <= 0: # auto-detect
    repetitionsCount = int(df[df.attrname == 'repetition']['attrvalue'].max()) + 1
print('Repetitions:', repetitionsCount)

# Computed
factorsCount = len(factors)

if saveFigures:
    os.makedirs('figures', exist_ok=True)
# Out:
# Repetitions: 10

# %%
scalars = df[(df.type == 'scalar') | ((df.type == 'itervar') & (df.attrname != 'TO')) | ((df.type == 'param') & (df.attrname == 'Floorplan.userCount')) | ((df.type == 'runattr') & (df.attrname == 'repetition'))]
scalars = scalars.assign(qname = scalars.attrname.combine_first(scalars.module + '.' + scalars.name))
for index, row in scalars[scalars.type == 'itervar'].iterrows():
    val = scalars.loc[index, 'attrvalue']
    if isinstance(val, str)  and not all(c.isdigit() for c in val):
        scalars.loc[index, 'attrvalue'] = eval(val)
scalars.value = scalars.value.combine_first(scalars.attrvalue.astype('float64'))
scalars_wide = scalars.pivot_table(index=['run'], columns='qname', values='value')
scalars_wide.sort_values([*factors, 'repetition'], inplace=True)
count = 0
for index in scalars_wide.index:
    config = count // repetitionsCount
    scalars_wide.loc[index, 'config'] = config
    count += 1
scalars_wide = scalars_wide[['config', 'repetition', *factors, *scalarsFilter]]

configsCount = int(scalars_wide['config'].max()) + 1
totalSims = configsCount*repetitionsCount
display(HTML("<style>div.output_scroll { height: auto; max-height: 48em; }</style>"))
pd.set_option('display.max_rows', totalSims)
pd.set_option('display.max_columns', 100)

# coverage
#scalars_wide['coveredUsersPercent'] = scalars_wide['Floorplan.coveredUsers:sum'] / (scalars_wide['Floorplan.userCount'] - 1)
# Out:
# <style>div.output_scroll { height: auto; max-height: 48em; }</style>

# %% [markdown]
# ## Load vectors

# %%
vectors = df[df.type == 'vector']
vectors = vectors.assign(qname = vectors.module + '.' + vectors.name)
for index in scalars_wide.index:
    r = index
    cfg = scalars_wide.loc[index, 'config']
    rep = scalars_wide.loc[index, 'repetition']
    vectors.loc[vectors.run == r, 'config'] = cfg
    vectors.loc[vectors.run == r, 'repetition'] = rep
vectors = vectors[vectors.qname.isin(vectorsFilter)]
vectors.sort_values(['config', 'repetition', 'qname'], inplace=True)
vectors = vectors[['config', 'repetition', 'qname', 'vectime', 'vecvalue']]

# %% [markdown]
# ## Compute scalars from vectors

# %%
def get_percentile(percentile, vectime, vecvalue, totalvalue):
    tofind = percentile * totalvalue
    idx = 0
    csum = vecvalue.cumsum()
    for value in csum:
        if value >= tofind:
            return vectime[idx]
        idx += 1
    return math.inf

for index, row in vectors.iterrows():
    for vecPerf, percentile in zip(vecPerfIndexes, percentiles):
        vecPerfIndex = vecPerf[0]
        cfg = row['config']
        rep = row['repetition']
        if vecPerfIndex.startswith('broadcastTime'):
            total = scalars_wide[(scalars_wide['config'] == cfg) & (scalars_wide['repetition'] == rep)]['Floorplan.userCount'].values[0] - 1
        else:
            raise Exception('Need to specify total for ' + vecPerfIndex + '. (coding required)')
        value = get_percentile(percentile, row['vectime'], row['vecvalue'], total)
        scalars_wide.loc[(scalars_wide['config'] == cfg) & (scalars_wide['repetition'] == rep), vecPerfIndex] = value

# %% [markdown]
# ## Apply transformations

# %%
for col, transform in transformations:
    scalars_wide[col] = scalars_wide[col].map(transform, 'ignore')

# %% [markdown]
# ## Full factorial

# %%
for cfg in range(0, configsCount):
    for perfIndex, _ in perfIndexes:
        mean = scalars_wide[scalars_wide['config'] == cfg][perfIndex].mean()
        variance = scalars_wide[scalars_wide['config'] == cfg][perfIndex].var()
        _, positiveInterval = tuple(v*math.sqrt(variance/repetitionsCount) for v in stats.t.interval(tIntervalAlpha, repetitionsCount - 1))
        negerr = positiveInterval
        poserr = positiveInterval
        if perfIndex == 'coveredUsersPercent':
            poserr = min(1 - mean, positiveInterval)
        if perfIndex == 'Floorplan.msgsPerSlot:sum':
            userCount = scalars_wide['Floorplan.userCount'].max()
            poserr = min(userCount - mean, positiveInterval)
        scalars_wide.loc[scalars_wide['config'] == cfg, perfIndex + 'Mean'] = mean
        scalars_wide.loc[scalars_wide['config'] == cfg, perfIndex + 'Variance'] = variance
        scalars_wide.loc[scalars_wide['config'] == cfg, perfIndex + 'Negerr'] = negerr
        scalars_wide.loc[scalars_wide['config'] == cfg, perfIndex + 'Poserr'] = poserr
scalars_wide = scalars_wide[scalars_wide['repetition'] == 0]

for perfIndex, _ in perfIndexes:
    del scalars_wide[perfIndex]
del scalars_wide['repetition']
del scalars_wide['Floorplan.userCount']
#del scalars_wide['Floorplan.coveredUsers:sum']
del scalars_wide['config']

scalars_wide
# Out:
# qname                                                R    T    m  \
# run
# HighDensityMessages-0-20210607-16:00:19-22977      8.0  2.0  2.0
# HighDensityMessages-70-20210607-16:01:18-23161     8.0  2.0  3.0
# HighDensityMessages-140-20210607-16:03:16-23460    8.0  2.0  4.0
# HighDensityMessages-210-20210607-16:05:20-23845    8.0  2.0  5.0
# HighDensityMessages-280-20210607-16:07:25-24142    8.0  3.0  2.0
# HighDensityMessages-350-20210607-16:08:27-24411    8.0  3.0  3.0
# HighDensityMessages-420-20210607-16:10:18-24671    8.0  3.0  4.0
# HighDensityMessages-490-20210607-16:12:18-24969    8.0  3.0  5.0
# HighDensityMessages-560-20210607-16:14:13-25269    8.0  4.0  2.0
# HighDensityMessages-630-20210607-16:15:25-25449    8.0  4.0  3.0
# HighDensityMessages-700-20210607-16:17:00-25674    8.0  4.0  4.0
# HighDensityMessages-770-20210607-16:19:01-25979    8.0  4.0  5.0
# HighDensityMessages-840-20210607-16:20:56-26277    8.0  5.0  2.0
# HighDensityMessages-910-20210607-16:22:17-26469    8.0  5.0  3.0
# HighDensityMessages-980-20210607-16:23:38-26657    8.0  5.0  4.0
# HighDensityMessages-1050-20210607-16:25:34-27006   8.0  5.0  5.0
# HighDensityMessages-10-20210607-16:00:19-22979     9.0  2.0  2.0
# HighDensityMessages-80-20210607-16:02:11-23308     9.0  2.0  3.0
# HighDensityMessages-150-20210607-16:03:21-23474    9.0  2.0  4.0
# HighDensityMessages-220-20210607-16:05:22-23851    9.0  2.0  5.0
# HighDensityMessages-290-20210607-16:07:28-24212    9.0  3.0  2.0
# HighDensityMessages-360-20210607-16:09:14-24516    9.0  3.0  3.0
# HighDensityMessages-430-20210607-16:10:28-24694    9.0  3.0  4.0
# HighDensityMessages-500-20210607-16:12:21-24977    9.0  3.0  5.0
# HighDensityMessages-570-20210607-16:14:22-25289    9.0  4.0  2.0
# HighDensityMessages-640-20210607-16:15:53-25509    9.0  4.0  3.0
# HighDensityMessages-710-20210607-16:17:22-25723    9.0  4.0  4.0
# HighDensityMessages-780-20210607-16:19:04-25985    9.0  4.0  5.0
# HighDensityMessages-850-20210607-16:21:05-26297    9.0  5.0  2.0
# HighDensityMessages-920-20210607-16:22:35-26507    9.0  5.0  3.0
# HighDensityMessages-990-20210607-16:24:12-26737    9.0  5.0  4.0
# HighDensityMessages-1060-20210607-16:25:41-27024   9.0  5.0  5.0
# HighDensityMessages-20-20210607-16:00:19-22981    10.0  2.0  2.0
# HighDensityMessages-90-20210607-16:02:13-23314    10.0  2.0  3.0
# HighDensityMessages-160-20210607-16:04:16-23606   10.0  2.0  4.0
# HighDensityMessages-230-20210607-16:05:26-23861   10.0  2.0  5.0
# HighDensityMessages-300-20210607-16:07:30-24252   10.0  3.0  2.0
# HighDensityMessages-370-20210607-16:09:14-24520   10.0  3.0  3.0
# HighDensityMessages-440-20210607-16:11:16-24805   10.0  3.0  4.0
# HighDensityMessages-510-20210607-16:12:32-25007   10.0  3.0  5.0
# HighDensityMessages-580-20210607-16:14:26-25301   10.0  4.0  2.0
# HighDensityMessages-650-20210607-16:16:00-25533   10.0  4.0  3.0
# HighDensityMessages-720-20210607-16:17:51-25784   10.0  4.0  4.0
# HighDensityMessages-790-20210607-16:19:26-26034   10.0  4.0  5.0
# HighDensityMessages-860-20210607-16:21:08-26305   10.0  5.0  2.0
# HighDensityMessages-930-20210607-16:22:40-26519   10.0  5.0  3.0
# HighDensityMessages-1000-20210607-16:24:28-26773  10.0  5.0  4.0
# HighDensityMessages-1070-20210607-16:26:17-27106  10.0  5.0  5.0
# HighDensityMessages-30-20210607-16:00:19-22983    11.0  2.0  2.0
# HighDensityMessages-100-20210607-16:02:14-23318   11.0  2.0  3.0
# HighDensityMessages-170-20210607-16:04:17-23613   11.0  2.0  4.0
# HighDensityMessages-240-20210607-16:06:22-23991   11.0  2.0  5.0
# HighDensityMessages-310-20210607-16:07:34-24272   11.0  3.0  2.0
# HighDensityMessages-380-20210607-16:09:18-24528   11.0  3.0  3.0
# HighDensityMessages-450-20210607-16:11:16-24807   11.0  3.0  4.0
# HighDensityMessages-520-20210607-16:13:11-25120   11.0  3.0  5.0
# HighDensityMessages-590-20210607-16:14:36-25323   11.0  4.0  2.0
# HighDensityMessages-660-20210607-16:16:01-25537   11.0  4.0  3.0
# HighDensityMessages-730-20210607-16:17:59-25806   11.0  4.0  4.0
# HighDensityMessages-800-20210607-16:19:54-26128   11.0  4.0  5.0
# HighDensityMessages-870-20210607-16:21:31-26356   11.0  5.0  2.0
# HighDensityMessages-940-20210607-16:22:41-26523   11.0  5.0  3.0
# HighDensityMessages-1010-20210607-16:24:32-26781  11.0  5.0  4.0
# HighDensityMessages-1080-20210607-16:26:30-27134  11.0  5.0  5.0
# HighDensityMessages-40-20210607-16:01:14-23147    12.0  2.0  2.0
# HighDensityMessages-110-20210607-16:02:18-23328   12.0  2.0  3.0
# HighDensityMessages-180-20210607-16:04:18-23615   12.0  2.0  4.0
# HighDensityMessages-250-20210607-16:06:25-23997   12.0  2.0  5.0
# HighDensityMessages-320-20210607-16:08:22-24393   12.0  3.0  2.0
# HighDensityMessages-390-20210607-16:09:28-24551   12.0  3.0  3.0
# HighDensityMessages-460-20210607-16:11:19-24818   12.0  3.0  4.0
# HighDensityMessages-530-20210607-16:13:19-25138   12.0  3.0  5.0
# HighDensityMessages-600-20210607-16:15:07-25401   12.0  4.0  2.0
# HighDensityMessages-670-20210607-16:16:26-25592   12.0  4.0  3.0
# HighDensityMessages-740-20210607-16:18:02-25814   12.0  4.0  4.0
# HighDensityMessages-810-20210607-16:20:02-26147   12.0  4.0  5.0
# HighDensityMessages-880-20210607-16:21:49-26396   12.0  5.0  2.0
# HighDensityMessages-950-20210607-16:23:15-26607   12.0  5.0  3.0
# HighDensityMessages-1020-20210607-16:24:39-26797  12.0  5.0  4.0
# HighDensityMessages-1090-20210607-16:26:36-27150  12.0  5.0  5.0
# HighDensityMessages-50-20210607-16:01:16-23153    13.0  2.0  2.0
# HighDensityMessages-120-20210607-16:03:14-23453   13.0  2.0  3.0
# HighDensityMessages-190-20210607-16:04:24-23629   13.0  2.0  4.0
# HighDensityMessages-260-20210607-16:06:26-24003   13.0  2.0  5.0
# HighDensityMessages-330-20210607-16:08:24-24397   13.0  3.0  2.0
# HighDensityMessages-400-20210607-16:10:14-24658   13.0  3.0  3.0
# HighDensityMessages-470-20210607-16:11:30-24840   13.0  3.0  4.0
# HighDensityMessages-540-20210607-16:13:23-25150   13.0  3.0  5.0
# HighDensityMessages-610-20210607-16:15:13-25420   13.0  4.0  2.0
# HighDensityMessages-680-20210607-16:16:53-25650   13.0  4.0  3.0
# HighDensityMessages-750-20210607-16:18:23-25861   13.0  4.0  4.0
# HighDensityMessages-820-20210607-16:20:05-26155   13.0  4.0  5.0
# HighDensityMessages-890-20210607-16:21:56-26418   13.0  5.0  2.0
# HighDensityMessages-960-20210607-16:23:33-26645   13.0  5.0  3.0
# HighDensityMessages-1030-20210607-16:25:16-26968  13.0  5.0  4.0
# HighDensityMessages-1100-20210607-16:26:45-27176  13.0  5.0  5.0
# HighDensityMessages-60-20210607-16:01:17-23157    14.0  2.0  2.0
# HighDensityMessages-130-20210607-16:03:15-23457   14.0  2.0  3.0
# HighDensityMessages-200-20210607-16:05:20-23843   14.0  2.0  4.0
# HighDensityMessages-270-20210607-16:06:30-24011   14.0  2.0  5.0
# HighDensityMessages-340-20210607-16:08:27-24407   14.0  3.0  2.0
# HighDensityMessages-410-20210607-16:10:15-24662   14.0  3.0  3.0
# HighDensityMessages-480-20210607-16:12:17-24963   14.0  3.0  4.0
# HighDensityMessages-550-20210607-16:13:34-25173   14.0  3.0  5.0
# HighDensityMessages-620-20210607-16:15:16-25427   14.0  4.0  2.0
# HighDensityMessages-690-20210607-16:16:59-25670   14.0  4.0  3.0
# HighDensityMessages-760-20210607-16:18:52-25953   14.0  4.0  4.0
# HighDensityMessages-830-20210607-16:20:28-26215   14.0  4.0  5.0
# HighDensityMessages-900-20210607-16:21:57-26422   14.0  5.0  2.0
# HighDensityMessages-970-20210607-16:23:37-26653   14.0  5.0  3.0
# HighDensityMessages-1040-20210607-16:25:29-26996  14.0  5.0  4.0
# HighDensityMessages-1110-20210607-16:27:19-27263  14.0  5.0  5.0
#
# qname                                             Floorplan.msgsPerSlot:sumMean  \
# run
# HighDensityMessages-0-20210607-16:00:19-22977                            1023.7
# HighDensityMessages-70-20210607-16:01:18-23161                           1112.2
# HighDensityMessages-140-20210607-16:03:16-23460                          1113.7
# HighDensityMessages-210-20210607-16:05:20-23845                          1111.9
# HighDensityMessages-280-20210607-16:07:25-24142                           990.7
# HighDensityMessages-350-20210607-16:08:27-24411                          1097.9
# HighDensityMessages-420-20210607-16:10:18-24671                          1120.3
# HighDensityMessages-490-20210607-16:12:18-24969                          1008.3
# HighDensityMessages-560-20210607-16:14:13-25269                           967.8
# HighDensityMessages-630-20210607-16:15:25-25449                          1087.0
# HighDensityMessages-700-20210607-16:17:00-25674                          1116.3
# HighDensityMessages-770-20210607-16:19:01-25979                          1117.4
# HighDensityMessages-840-20210607-16:20:56-26277                           955.4
# HighDensityMessages-910-20210607-16:22:17-26469                          1072.0
# HighDensityMessages-980-20210607-16:23:38-26657                          1110.0
# HighDensityMessages-1050-20210607-16:25:34-27006                         1117.2
# HighDensityMessages-10-20210607-16:00:19-22979                           1006.8
# HighDensityMessages-80-20210607-16:02:11-23308                           1119.5
# HighDensityMessages-150-20210607-16:03:21-23474                          1119.1
# HighDensityMessages-220-20210607-16:05:22-23851                          1118.0
# HighDensityMessages-290-20210607-16:07:28-24212                           955.3
# HighDensityMessages-360-20210607-16:09:14-24516                          1098.5
# HighDensityMessages-430-20210607-16:10:28-24694                          1121.9
# HighDensityMessages-500-20210607-16:12:21-24977                          1121.1
# HighDensityMessages-570-20210607-16:14:22-25289                           924.1
# HighDensityMessages-640-20210607-16:15:53-25509                          1069.2
# HighDensityMessages-710-20210607-16:17:22-25723                          1117.5
# HighDensityMessages-780-20210607-16:19:04-25985                          1121.7
# HighDensityMessages-850-20210607-16:21:05-26297                           930.4
# HighDensityMessages-920-20210607-16:22:35-26507                          1056.8
# HighDensityMessages-990-20210607-16:24:12-26737                          1113.4
# HighDensityMessages-1060-20210607-16:25:41-27024                         1116.3
# HighDensityMessages-20-20210607-16:00:19-22981                           1004.1
# HighDensityMessages-90-20210607-16:02:13-23314                           1120.2
# HighDensityMessages-160-20210607-16:04:16-23606                          1119.9
# HighDensityMessages-230-20210607-16:05:26-23861                          1119.4
# HighDensityMessages-300-20210607-16:07:30-24252                           924.8
# HighDensityMessages-370-20210607-16:09:14-24520                          1095.6
# HighDensityMessages-440-20210607-16:11:16-24805                          1121.0
# HighDensityMessages-510-20210607-16:12:32-25007                          1122.1
# HighDensityMessages-580-20210607-16:14:26-25301                           894.7
# HighDensityMessages-650-20210607-16:16:00-25533                          1063.5
# HighDensityMessages-720-20210607-16:17:51-25784                          1118.3
# HighDensityMessages-790-20210607-16:19:26-26034                          1122.3
# HighDensityMessages-860-20210607-16:21:08-26305                           879.6
# HighDensityMessages-930-20210607-16:22:40-26519                          1037.5
# HighDensityMessages-1000-20210607-16:24:28-26773                         1102.3
# HighDensityMessages-1070-20210607-16:26:17-27106                         1120.7
# HighDensityMessages-30-20210607-16:00:19-22983                           1018.3
# HighDensityMessages-100-20210607-16:02:14-23318                          1120.3
# HighDensityMessages-170-20210607-16:04:17-23613                          1118.4
# HighDensityMessages-240-20210607-16:06:22-23991                          1117.6
# HighDensityMessages-310-20210607-16:07:34-24272                           901.6
# HighDensityMessages-380-20210607-16:09:18-24528                          1089.7
# HighDensityMessages-450-20210607-16:11:16-24807                          1121.3
# HighDensityMessages-520-20210607-16:13:11-25120                          1121.4
# HighDensityMessages-590-20210607-16:14:36-25323                           862.8
# HighDensityMessages-660-20210607-16:16:01-25537                          1045.4
# HighDensityMessages-730-20210607-16:17:59-25806                          1116.2
# HighDensityMessages-800-20210607-16:19:54-26128                          1122.5
# HighDensityMessages-870-20210607-16:21:31-26356                           839.3
# HighDensityMessages-940-20210607-16:22:41-26523                          1013.6
# HighDensityMessages-1010-20210607-16:24:32-26781                         1102.7
# HighDensityMessages-1080-20210607-16:26:30-27134                         1122.0
# HighDensityMessages-40-20210607-16:01:14-23147                           1014.4
# HighDensityMessages-110-20210607-16:02:18-23328                          1120.4
# HighDensityMessages-180-20210607-16:04:18-23615                          1118.6
# HighDensityMessages-250-20210607-16:06:25-23997                          1119.4
# HighDensityMessages-320-20210607-16:08:22-24393                           910.6
# HighDensityMessages-390-20210607-16:09:28-24551                          1089.1
# HighDensityMessages-460-20210607-16:11:19-24818                          1121.8
# HighDensityMessages-530-20210607-16:13:19-25138                          1122.5
# HighDensityMessages-600-20210607-16:15:07-25401                           837.6
# HighDensityMessages-670-20210607-16:16:26-25592                          1039.3
# HighDensityMessages-740-20210607-16:18:02-25814                          1112.7
# HighDensityMessages-810-20210607-16:20:02-26147                          1123.7
# HighDensityMessages-880-20210607-16:21:49-26396                           824.9
# HighDensityMessages-950-20210607-16:23:15-26607                          1011.9
# HighDensityMessages-1020-20210607-16:24:39-26797                         1102.2
# HighDensityMessages-1090-20210607-16:26:36-27150                         1119.5
# HighDensityMessages-50-20210607-16:01:16-23153                           1019.1
# HighDensityMessages-120-20210607-16:03:14-23453                          1120.0
# HighDensityMessages-190-20210607-16:04:24-23629                          1117.0
# HighDensityMessages-260-20210607-16:06:26-24003                          1117.1
# HighDensityMessages-330-20210607-16:08:24-24397                           902.0
# HighDensityMessages-400-20210607-16:10:14-24658                          1096.2
# HighDensityMessages-470-20210607-16:11:30-24840                          1121.0
# HighDensityMessages-540-20210607-16:13:23-25150                          1120.8
# HighDensityMessages-610-20210607-16:15:13-25420                           812.4
# HighDensityMessages-680-20210607-16:16:53-25650                          1041.4
# HighDensityMessages-750-20210607-16:18:23-25861                          1116.0
# HighDensityMessages-820-20210607-16:20:05-26155                          1121.8
# HighDensityMessages-890-20210607-16:21:56-26418                           793.3
# HighDensityMessages-960-20210607-16:23:33-26645                          1005.0
# HighDensityMessages-1030-20210607-16:25:16-26968                         1102.9
# HighDensityMessages-1100-20210607-16:26:45-27176                         1122.2
# HighDensityMessages-60-20210607-16:01:17-23157                           1032.5
# HighDensityMessages-130-20210607-16:03:15-23457                          1116.0
# HighDensityMessages-200-20210607-16:05:20-23843                          1118.6
# HighDensityMessages-270-20210607-16:06:30-24011                          1118.8
# HighDensityMessages-340-20210607-16:08:27-24407                           913.9
# HighDensityMessages-410-20210607-16:10:15-24662                          1101.4
# HighDensityMessages-480-20210607-16:12:17-24963                          1121.1
# HighDensityMessages-550-20210607-16:13:34-25173                          1120.4
# HighDensityMessages-620-20210607-16:15:16-25427                           828.7
# HighDensityMessages-690-20210607-16:16:59-25670                          1056.4
# HighDensityMessages-760-20210607-16:18:52-25953                          1116.2
# HighDensityMessages-830-20210607-16:20:28-26215                          1123.9
# HighDensityMessages-900-20210607-16:21:57-26422                           791.9
# HighDensityMessages-970-20210607-16:23:37-26653                           989.3
# HighDensityMessages-1040-20210607-16:25:29-26996                         1101.0
# HighDensityMessages-1110-20210607-16:27:19-27263                         1122.0
#
# qname                                             Floorplan.msgsPerSlot:sumVariance  \
# run
# HighDensityMessages-0-20210607-16:00:19-22977                            264.233333
# HighDensityMessages-70-20210607-16:01:18-23161                            25.955556
# HighDensityMessages-140-20210607-16:03:16-23460                           10.011111
# HighDensityMessages-210-20210607-16:05:20-23845                          247.433333
# HighDensityMessages-280-20210607-16:07:25-24142                          231.344444
# HighDensityMessages-350-20210607-16:08:27-24411                           53.877778
# HighDensityMessages-420-20210607-16:10:18-24671                            2.455556
# HighDensityMessages-490-20210607-16:12:18-24969                       124031.788889
# HighDensityMessages-560-20210607-16:14:13-25269                           92.622222
# HighDensityMessages-630-20210607-16:15:25-25449                           24.222222
# HighDensityMessages-700-20210607-16:17:00-25674                           23.344444
# HighDensityMessages-770-20210607-16:19:01-25979                           16.488889
# HighDensityMessages-840-20210607-16:20:56-26277                          501.155556
# HighDensityMessages-910-20210607-16:22:17-26469                          573.333333
# HighDensityMessages-980-20210607-16:23:38-26657                          247.333333
# HighDensityMessages-1050-20210607-16:25:34-27006                           9.288889
# HighDensityMessages-10-20210607-16:00:19-22979                           149.288889
# HighDensityMessages-80-20210607-16:02:11-23308                            12.944444
# HighDensityMessages-150-20210607-16:03:21-23474                            8.988889
# HighDensityMessages-220-20210607-16:05:22-23851                           30.666667
# HighDensityMessages-290-20210607-16:07:28-24212                          195.788889
# HighDensityMessages-360-20210607-16:09:14-24516                           36.055556
# HighDensityMessages-430-20210607-16:10:28-24694                            2.988889
# HighDensityMessages-500-20210607-16:12:21-24977                           10.100000
# HighDensityMessages-570-20210607-16:14:22-25289                          568.322222
# HighDensityMessages-640-20210607-16:15:53-25509                          147.511111
# HighDensityMessages-710-20210607-16:17:22-25723                            5.833333
# HighDensityMessages-780-20210607-16:19:04-25985                            6.233333
# HighDensityMessages-850-20210607-16:21:05-26297                          374.933333
# HighDensityMessages-920-20210607-16:22:35-26507                          164.844444
# HighDensityMessages-990-20210607-16:24:12-26737                           33.600000
# HighDensityMessages-1060-20210607-16:25:41-27024                         157.566667
# HighDensityMessages-20-20210607-16:00:19-22981                           270.766667
# HighDensityMessages-90-20210607-16:02:13-23314                             4.844444
# HighDensityMessages-160-20210607-16:04:16-23606                            8.988889
# HighDensityMessages-230-20210607-16:05:26-23861                            8.488889
# HighDensityMessages-300-20210607-16:07:30-24252                          389.733333
# HighDensityMessages-370-20210607-16:09:14-24520                           73.155556
# HighDensityMessages-440-20210607-16:11:16-24805                            6.888889
# HighDensityMessages-510-20210607-16:12:32-25007                            2.766667
# HighDensityMessages-580-20210607-16:14:26-25301                          505.566667
# HighDensityMessages-650-20210607-16:16:00-25533                          109.166667
# HighDensityMessages-720-20210607-16:17:51-25784                            8.455556
# HighDensityMessages-790-20210607-16:19:26-26034                            1.788889
# HighDensityMessages-860-20210607-16:21:08-26305                         1227.822222
# HighDensityMessages-930-20210607-16:22:40-26519                          240.277778
# HighDensityMessages-1000-20210607-16:24:28-26773                         115.122222
# HighDensityMessages-1070-20210607-16:26:17-27106                          19.788889
# HighDensityMessages-30-20210607-16:00:19-22983                           148.233333
# HighDensityMessages-100-20210607-16:02:14-23318                            3.566667
# HighDensityMessages-170-20210607-16:04:17-23613                            6.933333
# HighDensityMessages-240-20210607-16:06:22-23991                           24.933333
# HighDensityMessages-310-20210607-16:07:34-24272                          238.933333
# HighDensityMessages-380-20210607-16:09:18-24528                           35.788889
# HighDensityMessages-450-20210607-16:11:16-24807                           17.122222
# HighDensityMessages-520-20210607-16:13:11-25120                           10.711111
# HighDensityMessages-590-20210607-16:14:36-25323                          633.733333
# HighDensityMessages-660-20210607-16:16:01-25537                          102.933333
# HighDensityMessages-730-20210607-16:17:59-25806                           13.733333
# HighDensityMessages-800-20210607-16:19:54-26128                            3.166667
# HighDensityMessages-870-20210607-16:21:31-26356                         1261.788889
# HighDensityMessages-940-20210607-16:22:41-26523                          168.711111
# HighDensityMessages-1010-20210607-16:24:32-26781                          34.233333
# HighDensityMessages-1080-20210607-16:26:30-27134                           2.888889
# HighDensityMessages-40-20210607-16:01:14-23147                           264.266667
# HighDensityMessages-110-20210607-16:02:18-23328                            6.488889
# HighDensityMessages-180-20210607-16:04:18-23615                           13.822222
# HighDensityMessages-250-20210607-16:06:25-23997                            9.822222
# HighDensityMessages-320-20210607-16:08:22-24393                          241.600000
# HighDensityMessages-390-20210607-16:09:28-24551                          104.100000
# HighDensityMessages-460-20210607-16:11:19-24818                           11.288889
# HighDensityMessages-530-20210607-16:13:19-25138                            4.277778
# HighDensityMessages-600-20210607-16:15:07-25401                         1009.377778
# HighDensityMessages-670-20210607-16:16:26-25592                          144.677778
# HighDensityMessages-740-20210607-16:18:02-25814                           54.900000
# HighDensityMessages-810-20210607-16:20:02-26147                            2.900000
# HighDensityMessages-880-20210607-16:21:49-26396                          243.433333
# HighDensityMessages-950-20210607-16:23:15-26607                          304.544444
# HighDensityMessages-1020-20210607-16:24:39-26797                          52.400000
# HighDensityMessages-1090-20210607-16:26:36-27150                           6.722222
# HighDensityMessages-50-20210607-16:01:16-23153                            71.655556
# HighDensityMessages-120-20210607-16:03:14-23453                            3.111111
# HighDensityMessages-190-20210607-16:04:24-23629                           21.555556
# HighDensityMessages-260-20210607-16:06:26-24003                            9.655556
# HighDensityMessages-330-20210607-16:08:24-24397                          706.000000
# HighDensityMessages-400-20210607-16:10:14-24658                          117.733333
# HighDensityMessages-470-20210607-16:11:30-24840                           10.666667
# HighDensityMessages-540-20210607-16:13:23-25150                            8.400000
# HighDensityMessages-610-20210607-16:15:13-25420                          627.377778
# HighDensityMessages-680-20210607-16:16:53-25650                          146.488889
# HighDensityMessages-750-20210607-16:18:23-25861                           22.000000
# HighDensityMessages-820-20210607-16:20:05-26155                            4.400000
# HighDensityMessages-890-20210607-16:21:56-26418                          622.455556
# HighDensityMessages-960-20210607-16:23:33-26645                          481.333333
# HighDensityMessages-1030-20210607-16:25:16-26968                          43.211111
# HighDensityMessages-1100-20210607-16:26:45-27176                           1.733333
# HighDensityMessages-60-20210607-16:01:17-23157                           221.388889
# HighDensityMessages-130-20210607-16:03:15-23457                           26.888889
# HighDensityMessages-200-20210607-16:05:20-23843                           13.377778
# HighDensityMessages-270-20210607-16:06:30-24011                           13.955556
# HighDensityMessages-340-20210607-16:08:27-24407                          545.655556
# HighDensityMessages-410-20210607-16:10:15-24662                           46.933333
# HighDensityMessages-480-20210607-16:12:17-24963                            6.766667
# HighDensityMessages-550-20210607-16:13:34-25173                            9.155556
# HighDensityMessages-620-20210607-16:15:16-25427                          635.122222
# HighDensityMessages-690-20210607-16:16:59-25670                          219.822222
# HighDensityMessages-760-20210607-16:18:52-25953                            9.955556
# HighDensityMessages-830-20210607-16:20:28-26215                            1.655556
# HighDensityMessages-900-20210607-16:21:57-26422                          618.766667
# HighDensityMessages-970-20210607-16:23:37-26653                          368.011111
# HighDensityMessages-1040-20210607-16:25:29-26996                          38.444444
# HighDensityMessages-1110-20210607-16:27:19-27263                           6.222222
#
# qname                                             Floorplan.msgsPerSlot:sumNegerr  \
# run
# HighDensityMessages-0-20210607-16:00:19-22977                           11.628309
# HighDensityMessages-70-20210607-16:01:18-23161                           3.644500
# HighDensityMessages-140-20210607-16:03:16-23460                          2.263414
# HighDensityMessages-210-20210607-16:05:20-23845                         11.252574
# HighDensityMessages-280-20210607-16:07:25-24142                         10.880587
# HighDensityMessages-350-20210607-16:08:27-24411                          5.250826
# HighDensityMessages-420-20210607-16:10:18-24671                          1.120979
# HighDensityMessages-490-20210607-16:12:18-24969                        251.935448
# HighDensityMessages-560-20210607-16:14:13-25269                          6.884626
# HighDensityMessages-630-20210607-16:15:25-25449                          3.520706
# HighDensityMessages-700-20210607-16:17:00-25674                          3.456325
# HighDensityMessages-770-20210607-16:19:01-25979                          2.904815
# HighDensityMessages-840-20210607-16:20:56-26277                         16.014340
# HighDensityMessages-910-20210607-16:22:17-26469                         17.128778
# HighDensityMessages-980-20210607-16:23:38-26657                         11.250300
# HighDensityMessages-1050-20210607-16:25:34-27006                         2.180242
# HighDensityMessages-10-20210607-16:00:19-22979                           8.740505
# HighDensityMessages-80-20210607-16:02:11-23308                           2.573739
# HighDensityMessages-150-20210607-16:03:21-23474                          2.144746
# HighDensityMessages-220-20210607-16:05:22-23851                          3.961467
# HighDensityMessages-290-20210607-16:07:28-24212                         10.009602
# HighDensityMessages-360-20210607-16:09:14-24516                          4.295452
# HighDensityMessages-430-20210607-16:10:28-24694                          1.236738
# HighDensityMessages-500-20210607-16:12:21-24977                          2.273440
# HighDensityMessages-570-20210607-16:14:22-25289                         17.053758
# HighDensityMessages-640-20210607-16:15:53-25509                          8.688307
# HighDensityMessages-710-20210607-16:17:22-25723                          1.727751
# HighDensityMessages-780-20210607-16:19:04-25985                          1.786006
# HighDensityMessages-850-20210607-16:21:05-26297                         13.851595
# HighDensityMessages-920-20210607-16:22:35-26507                          9.184593
# HighDensityMessages-990-20210607-16:24:12-26737                          4.146603
# HighDensityMessages-1060-20210607-16:25:41-27024                         8.979558
# HighDensityMessages-20-20210607-16:00:19-22981                          11.771190
# HighDensityMessages-90-20210607-16:02:13-23314                           1.574508
# HighDensityMessages-160-20210607-16:04:16-23606                          2.144746
# HighDensityMessages-230-20210607-16:05:26-23861                          2.084242
# HighDensityMessages-300-20210607-16:07:30-24252                         14.122336
# HighDensityMessages-370-20210607-16:09:14-24520                          6.118521
# HighDensityMessages-440-20210607-16:11:16-24805                          1.877575
# HighDensityMessages-510-20210607-16:12:32-25007                          1.189875
# HighDensityMessages-580-20210607-16:14:26-25301                         16.084664
# HighDensityMessages-650-20210607-16:16:00-25533                          7.474253
# HighDensityMessages-720-20210607-16:17:51-25784                          2.080146
# HighDensityMessages-790-20210607-16:19:26-26034                          0.956785
# HighDensityMessages-860-20210607-16:21:08-26305                         25.066316
# HighDensityMessages-930-20210607-16:22:40-26519                         11.088673
# HighDensityMessages-1000-20210607-16:24:28-26773                         7.675424
# HighDensityMessages-1070-20210607-16:26:17-27106                         3.182244
# HighDensityMessages-30-20210607-16:00:19-22983                           8.709550
# HighDensityMessages-100-20210607-16:02:14-23318                          1.350996
# HighDensityMessages-170-20210607-16:04:17-23613                          1.883622
# HighDensityMessages-240-20210607-16:06:22-23991                          3.572012
# HighDensityMessages-310-20210607-16:07:34-24272                         11.057607
# HighDensityMessages-380-20210607-16:09:18-24528                          4.279538
# HighDensityMessages-450-20210607-16:11:16-24807                          2.960076
# HighDensityMessages-520-20210607-16:13:11-25120                          2.341208
# HighDensityMessages-590-20210607-16:14:36-25323                         18.008438
# HighDensityMessages-660-20210607-16:16:01-25537                          7.257730
# HighDensityMessages-730-20210607-16:17:59-25806                          2.651006
# HighDensityMessages-800-20210607-16:19:54-26128                          1.272987
# HighDensityMessages-870-20210607-16:21:31-26356                         25.410670
# HighDensityMessages-940-20210607-16:22:41-26523                          9.291688
# HighDensityMessages-1010-20210607-16:24:32-26781                         4.185500
# HighDensityMessages-1080-20210607-16:26:30-27134                         1.215873
# HighDensityMessages-40-20210607-16:01:14-23147                          11.629043
# HighDensityMessages-110-20210607-16:02:18-23328                          1.822250
# HighDensityMessages-180-20210607-16:04:18-23615                          2.659572
# HighDensityMessages-250-20210607-16:06:25-23997                          2.241959
# HighDensityMessages-320-20210607-16:08:22-24393                         11.119141
# HighDensityMessages-390-20210607-16:09:28-24551                          7.298744
# HighDensityMessages-460-20210607-16:11:19-24818                          2.403524
# HighDensityMessages-530-20210607-16:13:19-25138                          1.479558
# HighDensityMessages-600-20210607-16:15:07-25401                         22.727394
# HighDensityMessages-670-20210607-16:16:26-25592                          8.604461
# HighDensityMessages-740-20210607-16:18:02-25814                          5.300404
# HighDensityMessages-810-20210607-16:20:02-26147                          1.218209
# HighDensityMessages-880-20210607-16:21:49-26396                         11.161249
# HighDensityMessages-950-20210607-16:23:15-26607                         12.483838
# HighDensityMessages-1020-20210607-16:24:39-26797                         5.178314
# HighDensityMessages-1090-20210607-16:26:36-27150                         1.854724
# HighDensityMessages-50-20210607-16:01:16-23153                           6.055468
# HighDensityMessages-120-20210607-16:03:14-23453                          1.261771
# HighDensityMessages-190-20210607-16:04:24-23629                          3.321256
# HighDensityMessages-260-20210607-16:06:26-24003                          2.222856
# HighDensityMessages-330-20210607-16:08:24-24397                         19.007505
# HighDensityMessages-400-20210607-16:10:14-24658                          7.761980
# HighDensityMessages-470-20210607-16:11:30-24840                          2.336346
# HighDensityMessages-540-20210607-16:13:23-25150                          2.073301
# HighDensityMessages-610-20210607-16:15:13-25420                         17.917910
# HighDensityMessages-680-20210607-16:16:53-25650                          8.658150
# HighDensityMessages-750-20210607-16:18:23-25861                          3.355321
# HighDensityMessages-820-20210607-16:20:05-26155                          1.500545
# HighDensityMessages-890-20210607-16:21:56-26418                         17.847482
# HighDensityMessages-960-20210607-16:23:33-26645                         15.694437
# HighDensityMessages-1030-20210607-16:25:16-26968                         4.702410
# HighDensityMessages-1100-20210607-16:26:45-27176                         0.941811
# HighDensityMessages-60-20210607-16:01:17-23157                          10.643898
# HighDensityMessages-130-20210607-16:03:15-23457                          3.709447
# HighDensityMessages-200-20210607-16:05:20-23843                          2.616464
# HighDensityMessages-270-20210607-16:06:30-24011                          2.672368
# HighDensityMessages-340-20210607-16:08:27-24407                         16.710216
# HighDensityMessages-410-20210607-16:10:15-24662                          4.900760
# HighDensityMessages-480-20210607-16:12:17-24963                          1.860845
# HighDensityMessages-550-20210607-16:13:34-25173                          2.164538
# HighDensityMessages-620-20210607-16:15:16-25427                         18.028161
# HighDensityMessages-690-20210607-16:16:59-25670                         10.606170
# HighDensityMessages-760-20210607-16:18:52-25953                          2.257125
# HighDensityMessages-830-20210607-16:20:28-26215                          0.920438
# HighDensityMessages-900-20210607-16:21:57-26422                         17.794518
# HighDensityMessages-970-20210607-16:23:37-26653                         13.723132
# HighDensityMessages-1040-20210607-16:25:29-26996                         4.435469
# HighDensityMessages-1110-20210607-16:27:19-27263                         1.784414
#
# qname                                             Floorplan.msgsPerSlot:sumPoserr
# run
# HighDensityMessages-0-20210607-16:00:19-22977                           11.628309
# HighDensityMessages-70-20210607-16:01:18-23161                           3.644500
# HighDensityMessages-140-20210607-16:03:16-23460                          2.263414
# HighDensityMessages-210-20210607-16:05:20-23845                         11.252574
# HighDensityMessages-280-20210607-16:07:25-24142                         10.880587
# HighDensityMessages-350-20210607-16:08:27-24411                          5.250826
# HighDensityMessages-420-20210607-16:10:18-24671                          1.120979
# HighDensityMessages-490-20210607-16:12:18-24969                        116.700000
# HighDensityMessages-560-20210607-16:14:13-25269                          6.884626
# HighDensityMessages-630-20210607-16:15:25-25449                          3.520706
# HighDensityMessages-700-20210607-16:17:00-25674                          3.456325
# HighDensityMessages-770-20210607-16:19:01-25979                          2.904815
# HighDensityMessages-840-20210607-16:20:56-26277                         16.014340
# HighDensityMessages-910-20210607-16:22:17-26469                         17.128778
# HighDensityMessages-980-20210607-16:23:38-26657                         11.250300
# HighDensityMessages-1050-20210607-16:25:34-27006                         2.180242
# HighDensityMessages-10-20210607-16:00:19-22979                           8.740505
# HighDensityMessages-80-20210607-16:02:11-23308                           2.573739
# HighDensityMessages-150-20210607-16:03:21-23474                          2.144746
# HighDensityMessages-220-20210607-16:05:22-23851                          3.961467
# HighDensityMessages-290-20210607-16:07:28-24212                         10.009602
# HighDensityMessages-360-20210607-16:09:14-24516                          4.295452
# HighDensityMessages-430-20210607-16:10:28-24694                          1.236738
# HighDensityMessages-500-20210607-16:12:21-24977                          2.273440
# HighDensityMessages-570-20210607-16:14:22-25289                         17.053758
# HighDensityMessages-640-20210607-16:15:53-25509                          8.688307
# HighDensityMessages-710-20210607-16:17:22-25723                          1.727751
# HighDensityMessages-780-20210607-16:19:04-25985                          1.786006
# HighDensityMessages-850-20210607-16:21:05-26297                         13.851595
# HighDensityMessages-920-20210607-16:22:35-26507                          9.184593
# HighDensityMessages-990-20210607-16:24:12-26737                          4.146603
# HighDensityMessages-1060-20210607-16:25:41-27024                         8.700000
# HighDensityMessages-20-20210607-16:00:19-22981                          11.771190
# HighDensityMessages-90-20210607-16:02:13-23314                           1.574508
# HighDensityMessages-160-20210607-16:04:16-23606                          2.144746
# HighDensityMessages-230-20210607-16:05:26-23861                          2.084242
# HighDensityMessages-300-20210607-16:07:30-24252                         14.122336
# HighDensityMessages-370-20210607-16:09:14-24520                          6.118521
# HighDensityMessages-440-20210607-16:11:16-24805                          1.877575
# HighDensityMessages-510-20210607-16:12:32-25007                          1.189875
# HighDensityMessages-580-20210607-16:14:26-25301                         16.084664
# HighDensityMessages-650-20210607-16:16:00-25533                          7.474253
# HighDensityMessages-720-20210607-16:17:51-25784                          2.080146
# HighDensityMessages-790-20210607-16:19:26-26034                          0.956785
# HighDensityMessages-860-20210607-16:21:08-26305                         25.066316
# HighDensityMessages-930-20210607-16:22:40-26519                         11.088673
# HighDensityMessages-1000-20210607-16:24:28-26773                         7.675424
# HighDensityMessages-1070-20210607-16:26:17-27106                         3.182244
# HighDensityMessages-30-20210607-16:00:19-22983                           8.709550
# HighDensityMessages-100-20210607-16:02:14-23318                          1.350996
# HighDensityMessages-170-20210607-16:04:17-23613                          1.883622
# HighDensityMessages-240-20210607-16:06:22-23991                          3.572012
# HighDensityMessages-310-20210607-16:07:34-24272                         11.057607
# HighDensityMessages-380-20210607-16:09:18-24528                          4.279538
# HighDensityMessages-450-20210607-16:11:16-24807                          2.960076
# HighDensityMessages-520-20210607-16:13:11-25120                          2.341208
# HighDensityMessages-590-20210607-16:14:36-25323                         18.008438
# HighDensityMessages-660-20210607-16:16:01-25537                          7.257730
# HighDensityMessages-730-20210607-16:17:59-25806                          2.651006
# HighDensityMessages-800-20210607-16:19:54-26128                          1.272987
# HighDensityMessages-870-20210607-16:21:31-26356                         25.410670
# HighDensityMessages-940-20210607-16:22:41-26523                          9.291688
# HighDensityMessages-1010-20210607-16:24:32-26781                         4.185500
# HighDensityMessages-1080-20210607-16:26:30-27134                         1.215873
# HighDensityMessages-40-20210607-16:01:14-23147                          11.629043
# HighDensityMessages-110-20210607-16:02:18-23328                          1.822250
# HighDensityMessages-180-20210607-16:04:18-23615                          2.659572
# HighDensityMessages-250-20210607-16:06:25-23997                          2.241959
# HighDensityMessages-320-20210607-16:08:22-24393                         11.119141
# HighDensityMessages-390-20210607-16:09:28-24551                          7.298744
# HighDensityMessages-460-20210607-16:11:19-24818                          2.403524
# HighDensityMessages-530-20210607-16:13:19-25138                          1.479558
# HighDensityMessages-600-20210607-16:15:07-25401                         22.727394
# HighDensityMessages-670-20210607-16:16:26-25592                          8.604461
# HighDensityMessages-740-20210607-16:18:02-25814                          5.300404
# HighDensityMessages-810-20210607-16:20:02-26147                          1.218209
# HighDensityMessages-880-20210607-16:21:49-26396                         11.161249
# HighDensityMessages-950-20210607-16:23:15-26607                         12.483838
# HighDensityMessages-1020-20210607-16:24:39-26797                         5.178314
# HighDensityMessages-1090-20210607-16:26:36-27150                         1.854724
# HighDensityMessages-50-20210607-16:01:16-23153                           6.055468
# HighDensityMessages-120-20210607-16:03:14-23453                          1.261771
# HighDensityMessages-190-20210607-16:04:24-23629                          3.321256
# HighDensityMessages-260-20210607-16:06:26-24003                          2.222856
# HighDensityMessages-330-20210607-16:08:24-24397                         19.007505
# HighDensityMessages-400-20210607-16:10:14-24658                          7.761980
# HighDensityMessages-470-20210607-16:11:30-24840                          2.336346
# HighDensityMessages-540-20210607-16:13:23-25150                          2.073301
# HighDensityMessages-610-20210607-16:15:13-25420                         17.917910
# HighDensityMessages-680-20210607-16:16:53-25650                          8.658150
# HighDensityMessages-750-20210607-16:18:23-25861                          3.355321
# HighDensityMessages-820-20210607-16:20:05-26155                          1.500545
# HighDensityMessages-890-20210607-16:21:56-26418                         17.847482
# HighDensityMessages-960-20210607-16:23:33-26645                         15.694437
# HighDensityMessages-1030-20210607-16:25:16-26968                         4.702410
# HighDensityMessages-1100-20210607-16:26:45-27176                         0.941811
# HighDensityMessages-60-20210607-16:01:17-23157                          10.643898
# HighDensityMessages-130-20210607-16:03:15-23457                          3.709447
# HighDensityMessages-200-20210607-16:05:20-23843                          2.616464
# HighDensityMessages-270-20210607-16:06:30-24011                          2.672368
# HighDensityMessages-340-20210607-16:08:27-24407                         16.710216
# HighDensityMessages-410-20210607-16:10:15-24662                          4.900760
# HighDensityMessages-480-20210607-16:12:17-24963                          1.860845
# HighDensityMessages-550-20210607-16:13:34-25173                          2.164538
# HighDensityMessages-620-20210607-16:15:16-25427                         18.028161
# HighDensityMessages-690-20210607-16:16:59-25670                         10.606170
# HighDensityMessages-760-20210607-16:18:52-25953                          2.257125
# HighDensityMessages-830-20210607-16:20:28-26215                          0.920438
# HighDensityMessages-900-20210607-16:21:57-26422                         17.794518
# HighDensityMessages-970-20210607-16:23:37-26653                         13.723132
# HighDensityMessages-1040-20210607-16:25:29-26996                         4.435469
# HighDensityMessages-1110-20210607-16:27:19-27263                         1.784414

# %%
for xFactor in factors:
    print('Plotting with', xFactor, 'on the x axis...')
    otherFactors = [fac for fac in factors if fac != xFactor]
    current = scalars_wide.sort_values([xFactor, *otherFactors])
    count = 0
    lastVal = None
    for index,row in current.iterrows():
        if lastVal != None and lastVal != row[xFactor]:
            count = 0
        current.loc[index, 'config'] = count
        count += 1
        lastVal = row[xFactor]
    x = current[xFactor].unique().tolist()
    for perfIndex, perfIndexDesc in perfIndexes:
        plt.figure(figsize=plotSize)
        plt.style.use(plotStyle)
        for cfg in range(0, int(current['config'].max()) + 1):
            y = current[current['config'] == cfg][perfIndex + 'Mean'].tolist()
            poserr = current[current['config'] == cfg][perfIndex + 'Poserr'].tolist()
            negerr = current[current['config'] == cfg][perfIndex + 'Negerr'].tolist()
            realy = []
            realx = []
            realne = []
            realpe = []
            curIdx = 0
            for val in y:
                if not math.isinf(val):
                    realy.append(val)
                    realx.append(x[curIdx])
                    realne.append(negerr[curIdx])
                    realpe.append(poserr[curIdx])
                curIdx += 1
            y = realy
            negerr = realne
            poserr = realpe
            err = [negerr, poserr]
            lbl = ""
            for fac in otherFactors:
                lbl += fac + '=' + str(current[current['config'] == cfg][fac].tolist()[0]) + ', '
            lbl = lbl[:-2]
            plt.errorbar(x=np.array(realx), y=np.array(y), yerr=np.array(err), capsize=3, linestyle='-', marker='.', markersize=10, label=lbl)
        plt.title('Full factorial plot for ' + perfIndexDesc)
        plt.ylabel(perfIndex)
        plt.xlabel(xFactor)
        plt.legend()
        if saveFigures:
            fig = plt.gcf()
            fig.savefig('figures/' + get_file_name(perfIndex) + '-' + xFactor + '-ffplot.png')
        plt.show()
    print('########################################')
    print()
# Out:
# Plotting with R on the x axis...
# ########################################
#
# Plotting with T on the x axis...
# ########################################
#
# Plotting with m on the x axis...
# ########################################

# %% [markdown]
# ## Observations
#
# Of course increasing the broadcast radius is the best way to increase the total number of messages sent, but since we want to optimize the energy efficiency of the network, this is not a viable way.
#
# We get a very large variance in the experiments with `R=8m; T=3s; m=5`. This is probably due to some experiment where the message have completely failed to reach more than just a bunch of users because of the low broadcast radius.
#
# If we want to avoid to increase `R`, we must reduce `m` and increase `T` to improve the energy efficiency. Probably it is best to avoid values lower than 9m or 10m for `R`, to avoid the huge increase in variance.
#
# For every value of `R`, except `R=9m`, the best config is with `T=5s` and `m=2`. In any case, with `R=9`, the config with `T=5s` and `m=2` is the second best config for the number of messages sent. Meaning that the combination of factors `T` and `m` are very important (contrarily to what our 2^kr analysis has found).
