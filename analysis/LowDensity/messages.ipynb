# %% [markdown]
# # Number of Messages Sent Factorial Analysis (Low Density Scenario)

# %%
import os
import math
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from itertools import product, chain, combinations
from scipy import stats
from IPython.display import display, HTML
# %matplotlib inline

def parse_if_number(s):
    try: return float(s)
    except: return True if s=="true" else False if s=="false" else s if s else None

def parse_ndarray(s):
    return np.fromstring(s, sep=' ') if s else None

def get_file_name(name):
    return name.replace(':', '-')

# %% [markdown]
# ## Config

# %%
inputFile = 'messages.csv'
repetitionsCount = -1 # -1 = auto-detect
factors = ['R', 'T', 'm']

tIntervalAlpha = 0.95

plotSize = (10, 10)
plotStyle = 'seaborn-whitegrid'
saveFigures = False

# Filter scalars
scalarsFilter = ['Floorplan.userCount', 'Floorplan.msgsPerSlot:sum']
# Filter vectors
vectorsFilter = []
# Percentiles
percentiles = [0.25, 0.5, 0.75, 0.9, 0.95]

# Performance indexes
perfIndexes = [
    ('Floorplan.msgsPerSlot:sum', 'total number of messages sent'),
]

# Transformations
transformations = [
]

intPercentiles = [int(i*100) for i in percentiles]
vecPerfIndexes = []
#for intPercentile in intPercentiles:
    #vecPerfIndexes.append(('broadcastTime' + str(intPercentile), 'Broadcast time needed to reach the ' + str(intPercentile) + 'th percentile of the coverage'))
for v in vecPerfIndexes:
    perfIndexes.append(v)
    #transformations.append((v[0], lambda x: math.log(x)))

# %% [markdown]
# ## Load scalars

# %%
df = pd.read_csv('exported_data/' + inputFile, converters = {
    'attrvalue': parse_if_number,
    'binedges': parse_ndarray,
    'binvalues': parse_ndarray,
    'vectime': parse_ndarray,
    'vecvalue': parse_ndarray,
})

# %%
if repetitionsCount <= 0: # auto-detect
    repetitionsCount = int(df[df.attrname == 'repetition']['attrvalue'].max()) + 1
print('Repetitions:', repetitionsCount)

# Computed
factorsCount = len(factors)

if saveFigures:
    os.makedirs('figures', exist_ok=True)
# Out:
# Repetitions: 10

# %%
scalars = df[(df.type == 'scalar') | ((df.type == 'itervar') & (df.attrname != 'TO')) | ((df.type == 'param') & (df.attrname == 'Floorplan.userCount')) | ((df.type == 'runattr') & (df.attrname == 'repetition'))]
scalars = scalars.assign(qname = scalars.attrname.combine_first(scalars.module + '.' + scalars.name))
for index, row in scalars[scalars.type == 'itervar'].iterrows():
    val = scalars.loc[index, 'attrvalue']
    if isinstance(val, str)  and not all(c.isdigit() for c in val):
        scalars.loc[index, 'attrvalue'] = eval(val)
scalars.value = scalars.value.combine_first(scalars.attrvalue.astype('float64'))
scalars_wide = scalars.pivot_table(index=['run'], columns='qname', values='value')
scalars_wide.sort_values([*factors, 'repetition'], inplace=True)
count = 0
for index in scalars_wide.index:
    config = count // repetitionsCount
    scalars_wide.loc[index, 'config'] = config
    count += 1
scalars_wide = scalars_wide[['config', 'repetition', *factors, *scalarsFilter]]

configsCount = int(scalars_wide['config'].max()) + 1
totalSims = configsCount*repetitionsCount
display(HTML("<style>div.output_scroll { height: auto; max-height: 48em; }</style>"))
pd.set_option('display.max_rows', totalSims)
pd.set_option('display.max_columns', 100)

# coverage
#scalars_wide['coveredUsersPercent'] = scalars_wide['Floorplan.coveredUsers:sum'] / (scalars_wide['Floorplan.userCount'] - 1)
# Out:
# <style>div.output_scroll { height: auto; max-height: 48em; }</style>

# %% [markdown]
# ## Load vectors

# %%
vectors = df[df.type == 'vector']
vectors = vectors.assign(qname = vectors.module + '.' + vectors.name)
for index in scalars_wide.index:
    r = index
    cfg = scalars_wide.loc[index, 'config']
    rep = scalars_wide.loc[index, 'repetition']
    vectors.loc[vectors.run == r, 'config'] = cfg
    vectors.loc[vectors.run == r, 'repetition'] = rep
vectors = vectors[vectors.qname.isin(vectorsFilter)]
vectors.sort_values(['config', 'repetition', 'qname'], inplace=True)
vectors = vectors[['config', 'repetition', 'qname', 'vectime', 'vecvalue']]

# %% [markdown]
# ## Compute scalars from vectors

# %%
def get_percentile(percentile, vectime, vecvalue, totalvalue):
    tofind = percentile * totalvalue
    idx = 0
    csum = vecvalue.cumsum()
    for value in csum:
        if value >= tofind:
            return vectime[idx]
        idx += 1
    return math.inf

for index, row in vectors.iterrows():
    for vecPerf, percentile in zip(vecPerfIndexes, percentiles):
        vecPerfIndex = vecPerf[0]
        cfg = row['config']
        rep = row['repetition']
        if vecPerfIndex.startswith('broadcastTime'):
            total = scalars_wide[(scalars_wide['config'] == cfg) & (scalars_wide['repetition'] == rep)]['Floorplan.userCount'].values[0] - 1
        else:
            raise Exception('Need to specify total for ' + vecPerfIndex + '. (coding required)')
        value = get_percentile(percentile, row['vectime'], row['vecvalue'], total)
        scalars_wide.loc[(scalars_wide['config'] == cfg) & (scalars_wide['repetition'] == rep), vecPerfIndex] = value

# %% [markdown]
# ## Apply transformations

# %%
for col, transform in transformations:
    scalars_wide[col] = scalars_wide[col].map(transform, 'ignore')

# %% [markdown]
# ## Full factorial

# %%
for cfg in range(0, configsCount):
    for perfIndex, _ in perfIndexes:
        mean = scalars_wide[scalars_wide['config'] == cfg][perfIndex].mean()
        variance = scalars_wide[scalars_wide['config'] == cfg][perfIndex].var()
        _, positiveInterval = tuple(v*math.sqrt(variance/repetitionsCount) for v in stats.t.interval(tIntervalAlpha, repetitionsCount - 1))
        negerr = positiveInterval
        poserr = positiveInterval
        if perfIndex == 'coveredUsersPercent':
            poserr = min(1 - mean, positiveInterval)
        if perfIndex == 'Floorplan.msgsPerSlot:sum':
            userCount = scalars_wide['Floorplan.userCount'].max()
            poserr = min(userCount - mean, positiveInterval)
        scalars_wide.loc[scalars_wide['config'] == cfg, perfIndex + 'Mean'] = mean
        scalars_wide.loc[scalars_wide['config'] == cfg, perfIndex + 'Variance'] = variance
        scalars_wide.loc[scalars_wide['config'] == cfg, perfIndex + 'Negerr'] = negerr
        scalars_wide.loc[scalars_wide['config'] == cfg, perfIndex + 'Poserr'] = poserr
scalars_wide = scalars_wide[scalars_wide['repetition'] == 0]

for perfIndex, _ in perfIndexes:
    del scalars_wide[perfIndex]
del scalars_wide['repetition']
del scalars_wide['Floorplan.userCount']
#del scalars_wide['Floorplan.coveredUsers:sum']
del scalars_wide['config']

scalars_wide
# Out:
# qname                                               R    T    m  \
# run
# LowDensityMessages-0-20210608-21:27:52-20225     23.0  2.0  2.0
# LowDensityMessages-130-20210608-21:31:44-20876   23.0  2.0  3.0
# LowDensityMessages-260-20210608-21:36:04-21511   23.0  2.0  4.0
# LowDensityMessages-390-20210608-21:40:27-22114   23.0  2.0  5.0
# LowDensityMessages-520-20210608-21:45:42-22989   23.0  3.0  2.0
# LowDensityMessages-650-20210608-21:49:55-23581   23.0  3.0  3.0
# LowDensityMessages-780-20210608-21:54:12-24167   23.0  3.0  4.0
# LowDensityMessages-910-20210608-21:58:36-24772   23.0  3.0  5.0
# LowDensityMessages-1040-20210608-22:03:35-25479  23.0  4.0  2.0
# LowDensityMessages-1170-20210608-22:07:43-26044  23.0  4.0  3.0
# LowDensityMessages-1300-20210608-22:12:12-26666  23.0  4.0  4.0
# LowDensityMessages-1430-20210608-22:16:38-27297  23.0  4.0  5.0
# LowDensityMessages-1560-20210608-22:21:16-27944  23.0  5.0  2.0
# LowDensityMessages-1690-20210608-22:25:36-28536  23.0  5.0  3.0
# LowDensityMessages-1820-20210608-22:30:06-29163  23.0  5.0  4.0
# LowDensityMessages-1950-20210608-22:34:30-29791  23.0  5.0  5.0
# LowDensityMessages-10-20210608-21:27:52-20227    24.0  2.0  2.0
# LowDensityMessages-140-20210608-21:31:45-20880   24.0  2.0  3.0
# LowDensityMessages-270-20210608-21:36:05-21515   24.0  2.0  4.0
# LowDensityMessages-400-20210608-21:41:22-22237   24.0  2.0  5.0
# LowDensityMessages-530-20210608-21:46:11-23060   24.0  3.0  2.0
# LowDensityMessages-660-20210608-21:49:55-23583   24.0  3.0  3.0
# LowDensityMessages-790-20210608-21:54:14-24173   24.0  3.0  4.0
# LowDensityMessages-920-20210608-21:59:16-24863   24.0  3.0  5.0
# LowDensityMessages-1050-20210608-22:04:05-25551  24.0  4.0  2.0
# LowDensityMessages-1180-20210608-22:08:01-26093  24.0  4.0  3.0
# LowDensityMessages-1310-20210608-22:12:13-26670  24.0  4.0  4.0
# LowDensityMessages-1440-20210608-22:16:54-27331  24.0  4.0  5.0
# LowDensityMessages-1570-20210608-22:21:58-28040  24.0  5.0  2.0
# LowDensityMessages-1700-20210608-22:25:57-28591  24.0  5.0  3.0
# LowDensityMessages-1830-20210608-22:30:09-29171  24.0  5.0  4.0
# LowDensityMessages-1960-20210608-22:34:33-29801  24.0  5.0  5.0
# LowDensityMessages-20-20210608-21:27:52-20229    25.0  2.0  2.0
# LowDensityMessages-150-20210608-21:31:46-20884   25.0  2.0  3.0
# LowDensityMessages-280-20210608-21:37:03-21642   25.0  2.0  4.0
# LowDensityMessages-410-20210608-21:41:48-22295   25.0  2.0  5.0
# LowDensityMessages-540-20210608-21:46:12-23064   25.0  3.0  2.0
# LowDensityMessages-670-20210608-21:49:56-23589   25.0  3.0  3.0
# LowDensityMessages-800-20210608-21:54:55-24267   25.0  3.0  4.0
# LowDensityMessages-930-20210608-21:59:44-24926   25.0  3.0  5.0
# LowDensityMessages-1060-20210608-22:04:25-25594  25.0  4.0  2.0
# LowDensityMessages-1190-20210608-22:08:01-26097  25.0  4.0  3.0
# LowDensityMessages-1320-20210608-22:12:33-26715  25.0  4.0  4.0
# LowDensityMessages-1450-20210608-22:17:36-27427  25.0  4.0  5.0
# LowDensityMessages-1580-20210608-22:22:21-28091  25.0  5.0  2.0
# LowDensityMessages-1710-20210608-22:25:59-28597  25.0  5.0  3.0
# LowDensityMessages-1840-20210608-22:30:12-29179  25.0  5.0  4.0
# LowDensityMessages-1970-20210608-22:35:20-29905  25.0  5.0  5.0
# LowDensityMessages-30-20210608-21:27:52-20231    26.0  2.0  2.0
# LowDensityMessages-160-20210608-21:33:01-21089   26.0  2.0  3.0
# LowDensityMessages-290-20210608-21:37:29-21695   26.0  2.0  4.0
# LowDensityMessages-420-20210608-21:41:51-22301   26.0  2.0  5.0
# LowDensityMessages-550-20210608-21:46:15-23072   26.0  3.0  2.0
# LowDensityMessages-680-20210608-21:50:40-23681   26.0  3.0  3.0
# LowDensityMessages-810-20210608-21:55:22-24325   26.0  3.0  4.0
# LowDensityMessages-940-20210608-22:00:02-24982   26.0  3.0  5.0
# LowDensityMessages-1070-20210608-22:04:26-25598  26.0  4.0  2.0
# LowDensityMessages-1200-20210608-22:08:24-26147  26.0  4.0  3.0
# LowDensityMessages-1330-20210608-22:13:16-26810  26.0  4.0  4.0
# LowDensityMessages-1460-20210608-22:17:58-27483  26.0  4.0  5.0
# LowDensityMessages-1590-20210608-22:22:28-28107  26.0  5.0  2.0
# LowDensityMessages-1720-20210608-22:26:04-28611  26.0  5.0  3.0
# LowDensityMessages-1850-20210608-22:31:03-29292  26.0  5.0  4.0
# LowDensityMessages-1980-20210608-22:35:50-29969  26.0  5.0  5.0
# LowDensityMessages-40-20210608-21:29:09-20510    27.0  2.0  2.0
# LowDensityMessages-170-20210608-21:33:10-21107   27.0  2.0  3.0
# LowDensityMessages-300-20210608-21:37:31-21701   27.0  2.0  4.0
# LowDensityMessages-430-20210608-21:41:52-22306   27.0  2.0  5.0
# LowDensityMessages-560-20210608-21:47:00-23171   27.0  3.0  2.0
# LowDensityMessages-690-20210608-21:51:20-23774   27.0  3.0  3.0
# LowDensityMessages-820-20210608-21:55:37-24356   27.0  3.0  4.0
# LowDensityMessages-950-20210608-22:00:03-24991   27.0  3.0  5.0
# LowDensityMessages-1080-20210608-22:04:53-25655  27.0  4.0  2.0
# LowDensityMessages-1210-20210608-22:09:09-26253  27.0  4.0  3.0
# LowDensityMessages-1340-20210608-22:13:37-26855  27.0  4.0  4.0
# LowDensityMessages-1470-20210608-22:18:05-27500  27.0  4.0  5.0
# LowDensityMessages-1600-20210608-22:22:32-28115  27.0  5.0  2.0
# LowDensityMessages-1730-20210608-22:27:00-28733  27.0  5.0  3.0
# LowDensityMessages-1860-20210608-22:31:34-29354  27.0  5.0  4.0
# LowDensityMessages-1990-20210608-22:35:58-29994  27.0  5.0  5.0
# LowDensityMessages-50-20210608-21:29:10-20514    28.0  2.0  2.0
# LowDensityMessages-180-20210608-21:33:11-21111   28.0  2.0  3.0
# LowDensityMessages-310-20210608-21:37:32-21705   28.0  2.0  4.0
# LowDensityMessages-440-20210608-21:42:48-22491   28.0  2.0  5.0
# LowDensityMessages-570-20210608-21:47:28-23231   28.0  3.0  2.0
# LowDensityMessages-700-20210608-21:51:22-23778   28.0  3.0  3.0
# LowDensityMessages-830-20210608-21:55:41-24366   28.0  3.0  4.0
# LowDensityMessages-960-20210608-22:00:42-25072   28.0  3.0  5.0
# LowDensityMessages-1090-20210608-22:05:22-25724  28.0  4.0  2.0
# LowDensityMessages-1220-20210608-22:09:26-26290  28.0  4.0  3.0
# LowDensityMessages-1350-20210608-22:13:41-26865  28.0  4.0  4.0
# LowDensityMessages-1480-20210608-22:18:19-27534  28.0  4.0  5.0
# LowDensityMessages-1610-20210608-22:23:15-28215  28.0  5.0  2.0
# LowDensityMessages-1740-20210608-22:27:22-28781  28.0  5.0  3.0
# LowDensityMessages-1870-20210608-22:31:36-29362  28.0  5.0  4.0
# LowDensityMessages-2000-20210608-22:36:00-30000  28.0  5.0  5.0
# LowDensityMessages-60-20210608-21:29:10-20517    29.0  2.0  2.0
# LowDensityMessages-190-20210608-21:33:11-21115   29.0  2.0  3.0
# LowDensityMessages-320-20210608-21:38:30-21840   29.0  2.0  4.0
# LowDensityMessages-450-20210608-21:43:16-22597   29.0  2.0  5.0
# LowDensityMessages-580-20210608-21:47:29-23233   29.0  3.0  2.0
# LowDensityMessages-710-20210608-21:51:24-23784   29.0  3.0  3.0
# LowDensityMessages-840-20210608-21:56:21-24461   29.0  3.0  4.0
# LowDensityMessages-970-20210608-22:01:11-25148   29.0  3.0  5.0
# LowDensityMessages-1100-20210608-22:05:41-25764  29.0  4.0  2.0
# LowDensityMessages-1230-20210608-22:09:27-26294  29.0  4.0  3.0
# LowDensityMessages-1360-20210608-22:14:00-26915  29.0  4.0  4.0
# LowDensityMessages-1490-20210608-22:19:03-27631  29.0  4.0  5.0
# LowDensityMessages-1620-20210608-22:23:37-28264  29.0  5.0  2.0
# LowDensityMessages-1750-20210608-22:27:23-28785  29.0  5.0  3.0
# LowDensityMessages-1880-20210608-22:31:41-29375  29.0  5.0  4.0
# LowDensityMessages-2010-20210608-22:36:48-30100  29.0  5.0  5.0
# LowDensityMessages-70-20210608-21:29:11-20519    30.0  2.0  2.0
# LowDensityMessages-200-20210608-21:34:11-21251   30.0  2.0  3.0
# LowDensityMessages-330-20210608-21:38:56-21901   30.0  2.0  4.0
# LowDensityMessages-460-20210608-21:43:17-22610   30.0  2.0  5.0
# LowDensityMessages-590-20210608-21:47:33-23243   30.0  3.0  2.0
# LowDensityMessages-720-20210608-21:52:05-23881   30.0  3.0  3.0
# LowDensityMessages-850-20210608-21:56:49-24519   30.0  3.0  4.0
# LowDensityMessages-980-20210608-22:01:29-25187   30.0  3.0  5.0
# LowDensityMessages-1110-20210608-22:05:42-25770  30.0  4.0  2.0
# LowDensityMessages-1240-20210608-22:09:48-26339  30.0  4.0  3.0
# LowDensityMessages-1370-20210608-22:14:44-27011  30.0  4.0  4.0
# LowDensityMessages-1500-20210608-22:19:25-27683  30.0  4.0  5.0
# LowDensityMessages-1630-20210608-22:23:43-28276  30.0  5.0  2.0
# LowDensityMessages-1760-20210608-22:27:28-28797  30.0  5.0  3.0
# LowDensityMessages-1890-20210608-22:32:31-29486  30.0  5.0  4.0
# LowDensityMessages-2020-20210608-22:37:17-30168  30.0  5.0  5.0
# LowDensityMessages-80-20210608-21:30:26-20689    31.0  2.0  2.0
# LowDensityMessages-210-20210608-21:34:36-21308   31.0  2.0  3.0
# LowDensityMessages-340-20210608-21:38:57-21905   31.0  2.0  4.0
# LowDensityMessages-470-20210608-21:43:18-22618   31.0  2.0  5.0
# LowDensityMessages-600-20210608-21:48:15-23348   31.0  3.0  2.0
# LowDensityMessages-730-20210608-21:52:45-23964   31.0  3.0  3.0
# LowDensityMessages-860-20210608-21:57:06-24561   31.0  3.0  4.0
# LowDensityMessages-990-20210608-22:01:30-25191   31.0  3.0  5.0
# LowDensityMessages-1120-20210608-22:06:06-25830  31.0  4.0  2.0
# LowDensityMessages-1250-20210608-22:10:33-26440  31.0  4.0  3.0
# LowDensityMessages-1380-20210608-22:15:05-27063  31.0  4.0  4.0
# LowDensityMessages-1510-20210608-22:19:33-27701  31.0  4.0  5.0
# LowDensityMessages-1640-20210608-22:23:46-28284  31.0  5.0  2.0
# LowDensityMessages-1770-20210608-22:28:23-28919  31.0  5.0  3.0
# LowDensityMessages-1900-20210608-22:33:00-29586  31.0  5.0  4.0
# LowDensityMessages-2030-20210608-22:37:26-30196  31.0  5.0  5.0
# LowDensityMessages-90-20210608-21:30:27-20693    32.0  2.0  2.0
# LowDensityMessages-220-20210608-21:34:37-21312   32.0  2.0  3.0
# LowDensityMessages-350-20210608-21:38:59-21915   32.0  2.0  4.0
# LowDensityMessages-480-20210608-21:44:15-22789   32.0  2.0  5.0
# LowDensityMessages-610-20210608-21:48:43-23407   32.0  3.0  2.0
# LowDensityMessages-740-20210608-21:52:48-23970   32.0  3.0  3.0
# LowDensityMessages-870-20210608-21:57:08-24567   32.0  3.0  4.0
# LowDensityMessages-1000-20210608-22:02:09-25284  32.0  3.0  5.0
# LowDensityMessages-1130-20210608-22:06:34-25888  32.0  4.0  2.0
# LowDensityMessages-1260-20210608-22:10:50-26477  32.0  4.0  3.0
# LowDensityMessages-1390-20210608-22:15:09-27073  32.0  4.0  4.0
# LowDensityMessages-1520-20210608-22:19:47-27734  32.0  4.0  5.0
# LowDensityMessages-1650-20210608-22:24:28-28382  32.0  5.0  2.0
# LowDensityMessages-1780-20210608-22:28:45-28967  32.0  5.0  3.0
# LowDensityMessages-1910-20210608-22:33:04-29598  32.0  5.0  4.0
# LowDensityMessages-2040-20210608-22:37:29-30213  32.0  5.0  5.0
# LowDensityMessages-100-20210608-21:30:27-20695   33.0  2.0  2.0
# LowDensityMessages-230-20210608-21:34:38-21316   33.0  2.0  3.0
# LowDensityMessages-360-20210608-21:39:58-22052   33.0  2.0  4.0
# LowDensityMessages-490-20210608-21:44:44-22855   33.0  2.0  5.0
# LowDensityMessages-620-20210608-21:48:44-23411   33.0  3.0  2.0
# LowDensityMessages-750-20210608-21:52:50-23976   33.0  3.0  3.0
# LowDensityMessages-880-20210608-21:57:49-24655   33.0  3.0  4.0
# LowDensityMessages-1010-20210608-22:02:38-25350  33.0  3.0  5.0
# LowDensityMessages-1140-20210608-22:06:53-25928  33.0  4.0  2.0
# LowDensityMessages-1270-20210608-22:10:51-26481  33.0  4.0  3.0
# LowDensityMessages-1400-20210608-22:15:27-27129  33.0  4.0  4.0
# LowDensityMessages-1530-20210608-22:20:30-27836  33.0  4.0  5.0
# LowDensityMessages-1660-20210608-22:24:49-28427  33.0  5.0  2.0
# LowDensityMessages-1790-20210608-22:28:47-28973  33.0  5.0  3.0
# LowDensityMessages-1920-20210608-22:33:09-29608  33.0  5.0  4.0
# LowDensityMessages-2050-20210608-22:38:16-30365  33.0  5.0  5.0
# LowDensityMessages-110-20210608-21:30:28-20699   34.0  2.0  2.0
# LowDensityMessages-240-20210608-21:35:37-21443   34.0  2.0  3.0
# LowDensityMessages-370-20210608-21:40:23-22104   34.0  2.0  4.0
# LowDensityMessages-500-20210608-21:44:44-22859   34.0  2.0  5.0
# LowDensityMessages-630-20210608-21:48:45-23415   34.0  3.0  2.0
# LowDensityMessages-760-20210608-21:53:30-24067   34.0  3.0  3.0
# LowDensityMessages-890-20210608-21:58:15-24719   34.0  3.0  4.0
# LowDensityMessages-1020-20210608-22:02:57-25397  34.0  3.0  5.0
# LowDensityMessages-1150-20210608-22:06:54-25932  34.0  4.0  2.0
# LowDensityMessages-1280-20210608-22:11:11-26532  34.0  4.0  3.0
# LowDensityMessages-1410-20210608-22:16:10-27236  34.0  4.0  4.0
# LowDensityMessages-1540-20210608-22:20:52-27881  34.0  4.0  5.0
# LowDensityMessages-1670-20210608-22:24:52-28435  34.0  5.0  2.0
# LowDensityMessages-1800-20210608-22:28:51-28984  34.0  5.0  3.0
# LowDensityMessages-1930-20210608-22:33:55-29711  34.0  5.0  4.0
# LowDensityMessages-2060-20210608-22:38:45-30457  34.0  5.0  5.0
# LowDensityMessages-120-20210608-21:31:43-20872   35.0  2.0  2.0
# LowDensityMessages-250-20210608-21:36:03-21507   35.0  2.0  3.0
# LowDensityMessages-380-20210608-21:40:25-22108   35.0  2.0  4.0
# LowDensityMessages-510-20210608-21:44:46-22865   35.0  2.0  5.0
# LowDensityMessages-640-20210608-21:49:28-23515   35.0  3.0  2.0
# LowDensityMessages-770-20210608-21:54:10-24161   35.0  3.0  3.0
# LowDensityMessages-900-20210608-21:58:33-24765   35.0  3.0  4.0
# LowDensityMessages-1030-20210608-22:02:58-25401  35.0  3.0  5.0
# LowDensityMessages-1160-20210608-22:07:15-25985  35.0  4.0  2.0
# LowDensityMessages-1290-20210608-22:11:55-26628  35.0  4.0  3.0
# LowDensityMessages-1420-20210608-22:16:31-27280  35.0  4.0  4.0
# LowDensityMessages-1550-20210608-22:21:01-27909  35.0  4.0  5.0
# LowDensityMessages-1680-20210608-22:24:57-28454  35.0  5.0  2.0
# LowDensityMessages-1810-20210608-22:29:44-29108  35.0  5.0  3.0
# LowDensityMessages-1940-20210608-22:34:24-29779  35.0  5.0  4.0
# LowDensityMessages-2070-20210608-22:38:54-30479  35.0  5.0  5.0
#
# qname                                            Floorplan.msgsPerSlot:sumMean  \
# run
# LowDensityMessages-0-20210608-21:27:52-20225                            1147.5
# LowDensityMessages-130-20210608-21:31:44-20876                          1233.2
# LowDensityMessages-260-20210608-21:36:04-21511                          1234.6
# LowDensityMessages-390-20210608-21:40:27-22114                          1229.2
# LowDensityMessages-520-20210608-21:45:42-22989                          1101.3
# LowDensityMessages-650-20210608-21:49:55-23581                          1214.2
# LowDensityMessages-780-20210608-21:54:12-24167                          1110.7
# LowDensityMessages-910-20210608-21:58:36-24772                          1237.4
# LowDensityMessages-1040-20210608-22:03:35-25479                         1113.4
# LowDensityMessages-1170-20210608-22:07:43-26044                         1197.7
# LowDensityMessages-1300-20210608-22:12:12-26666                         1223.3
# LowDensityMessages-1430-20210608-22:16:38-27297                         1233.0
# LowDensityMessages-1560-20210608-22:21:16-27944                         1093.9
# LowDensityMessages-1690-20210608-22:25:36-28536                         1207.2
# LowDensityMessages-1820-20210608-22:30:06-29163                         1230.0
# LowDensityMessages-1950-20210608-22:34:30-29791                         1234.0
# LowDensityMessages-10-20210608-21:27:52-20227                           1141.3
# LowDensityMessages-140-20210608-21:31:45-20880                          1238.1
# LowDensityMessages-270-20210608-21:36:05-21515                          1233.6
# LowDensityMessages-400-20210608-21:41:22-22237                          1234.2
# LowDensityMessages-530-20210608-21:46:11-23060                          1108.0
# LowDensityMessages-660-20210608-21:49:55-23583                          1226.4
# LowDensityMessages-790-20210608-21:54:14-24173                          1240.2
# LowDensityMessages-920-20210608-21:59:16-24863                          1238.2
# LowDensityMessages-1050-20210608-22:04:05-25551                         1102.3
# LowDensityMessages-1180-20210608-22:08:01-26093                         1207.4
# LowDensityMessages-1310-20210608-22:12:13-26670                         1235.8
# LowDensityMessages-1440-20210608-22:16:54-27331                         1232.4
# LowDensityMessages-1570-20210608-22:21:58-28040                         1090.4
# LowDensityMessages-1700-20210608-22:25:57-28591                         1203.4
# LowDensityMessages-1830-20210608-22:30:09-29171                         1232.2
# LowDensityMessages-1960-20210608-22:34:33-29801                         1239.3
# LowDensityMessages-20-20210608-21:27:52-20229                           1145.5
# LowDensityMessages-150-20210608-21:31:46-20884                          1236.2
# LowDensityMessages-280-20210608-21:37:03-21642                          1239.7
# LowDensityMessages-410-20210608-21:41:48-22295                          1238.7
# LowDensityMessages-540-20210608-21:46:12-23064                          1087.2
# LowDensityMessages-670-20210608-21:49:56-23589                          1224.6
# LowDensityMessages-800-20210608-21:54:55-24267                          1239.7
# LowDensityMessages-930-20210608-21:59:44-24926                          1238.2
# LowDensityMessages-1060-20210608-22:04:25-25594                         1077.4
# LowDensityMessages-1190-20210608-22:08:01-26097                         1213.3
# LowDensityMessages-1320-20210608-22:12:33-26715                         1236.7
# LowDensityMessages-1450-20210608-22:17:36-27427                         1242.8
# LowDensityMessages-1580-20210608-22:22:21-28091                         1062.7
# LowDensityMessages-1710-20210608-22:25:59-28597                         1197.3
# LowDensityMessages-1840-20210608-22:30:12-29179                         1238.3
# LowDensityMessages-1970-20210608-22:35:20-29905                         1242.4
# LowDensityMessages-30-20210608-21:27:52-20231                           1138.4
# LowDensityMessages-160-20210608-21:33:01-21089                          1119.0
# LowDensityMessages-290-20210608-21:37:29-21695                          1239.9
# LowDensityMessages-420-20210608-21:41:51-22301                          1236.4
# LowDensityMessages-550-20210608-21:46:15-23072                          1089.9
# LowDensityMessages-680-20210608-21:50:40-23681                          1219.8
# LowDensityMessages-810-20210608-21:55:22-24325                          1243.5
# LowDensityMessages-940-20210608-22:00:02-24982                          1244.0
# LowDensityMessages-1070-20210608-22:04:26-25598                         1066.6
# LowDensityMessages-1200-20210608-22:08:24-26147                         1199.0
# LowDensityMessages-1330-20210608-22:13:16-26810                         1239.8
# LowDensityMessages-1460-20210608-22:17:58-27483                         1243.0
# LowDensityMessages-1590-20210608-22:22:28-28107                         1065.9
# LowDensityMessages-1720-20210608-22:26:04-28611                         1194.8
# LowDensityMessages-1850-20210608-22:31:03-29292                         1236.0
# LowDensityMessages-1980-20210608-22:35:50-29969                         1241.4
# LowDensityMessages-40-20210608-21:29:09-20510                           1141.9
# LowDensityMessages-170-20210608-21:33:10-21107                          1242.2
# LowDensityMessages-300-20210608-21:37:31-21701                          1243.3
# LowDensityMessages-430-20210608-21:41:52-22306                          1242.1
# LowDensityMessages-560-20210608-21:47:00-23171                          1083.3
# LowDensityMessages-690-20210608-21:51:20-23774                          1217.4
# LowDensityMessages-820-20210608-21:55:37-24356                          1241.9
# LowDensityMessages-950-20210608-22:00:03-24991                          1242.9
# LowDensityMessages-1080-20210608-22:04:53-25655                         1052.8
# LowDensityMessages-1210-20210608-22:09:09-26253                         1196.1
# LowDensityMessages-1340-20210608-22:13:37-26855                         1239.5
# LowDensityMessages-1470-20210608-22:18:05-27500                         1243.3
# LowDensityMessages-1600-20210608-22:22:32-28115                         1036.3
# LowDensityMessages-1730-20210608-22:27:00-28733                         1185.7
# LowDensityMessages-1860-20210608-22:31:34-29354                         1234.8
# LowDensityMessages-1990-20210608-22:35:58-29994                         1245.3
# LowDensityMessages-50-20210608-21:29:10-20514                           1124.1
# LowDensityMessages-180-20210608-21:33:11-21111                          1245.6
# LowDensityMessages-310-20210608-21:37:32-21705                          1243.9
# LowDensityMessages-440-20210608-21:42:48-22491                          1242.4
# LowDensityMessages-570-20210608-21:47:28-23231                          1066.7
# LowDensityMessages-700-20210608-21:51:22-23778                          1225.3
# LowDensityMessages-830-20210608-21:55:41-24366                          1246.8
# LowDensityMessages-960-20210608-22:00:42-25072                          1245.2
# LowDensityMessages-1090-20210608-22:05:22-25724                         1035.8
# LowDensityMessages-1220-20210608-22:09:26-26290                         1197.9
# LowDensityMessages-1350-20210608-22:13:41-26865                         1240.2
# LowDensityMessages-1480-20210608-22:18:19-27534                         1246.8
# LowDensityMessages-1610-20210608-22:23:15-28215                         1018.9
# LowDensityMessages-1740-20210608-22:27:22-28781                         1183.1
# LowDensityMessages-1870-20210608-22:31:36-29362                         1234.6
# LowDensityMessages-2000-20210608-22:36:00-30000                         1246.3
# LowDensityMessages-60-20210608-21:29:10-20517                           1131.1
# LowDensityMessages-190-20210608-21:33:11-21115                          1243.9
# LowDensityMessages-320-20210608-21:38:30-21840                          1244.4
# LowDensityMessages-450-20210608-21:43:16-22597                          1241.8
# LowDensityMessages-580-20210608-21:47:29-23233                          1053.2
# LowDensityMessages-710-20210608-21:51:24-23784                          1220.6
# LowDensityMessages-840-20210608-21:56:21-24461                          1245.6
# LowDensityMessages-970-20210608-22:01:11-25148                          1244.5
# LowDensityMessages-1100-20210608-22:05:41-25764                         1010.0
# LowDensityMessages-1230-20210608-22:09:27-26294                         1190.7
# LowDensityMessages-1360-20210608-22:14:00-26915                         1241.7
# LowDensityMessages-1490-20210608-22:19:03-27631                         1247.3
# LowDensityMessages-1620-20210608-22:23:37-28264                         1003.4
# LowDensityMessages-1750-20210608-22:27:23-28785                         1169.6
# LowDensityMessages-1880-20210608-22:31:41-29375                         1233.8
# LowDensityMessages-2010-20210608-22:36:48-30100                         1245.4
# LowDensityMessages-70-20210608-21:29:11-20519                           1119.0
# LowDensityMessages-200-20210608-21:34:11-21251                          1244.6
# LowDensityMessages-330-20210608-21:38:56-21901                          1244.4
# LowDensityMessages-460-20210608-21:43:17-22610                          1243.1
# LowDensityMessages-590-20210608-21:47:33-23243                          1032.9
# LowDensityMessages-720-20210608-21:52:05-23881                          1218.1
# LowDensityMessages-850-20210608-21:56:49-24519                          1246.2
# LowDensityMessages-980-20210608-22:01:29-25187                          1245.4
# LowDensityMessages-1110-20210608-22:05:42-25770                          992.4
# LowDensityMessages-1240-20210608-22:09:48-26339                         1180.3
# LowDensityMessages-1370-20210608-22:14:44-27011                         1242.5
# LowDensityMessages-1500-20210608-22:19:25-27683                         1248.3
# LowDensityMessages-1630-20210608-22:23:43-28276                          989.3
# LowDensityMessages-1760-20210608-22:27:28-28797                         1165.2
# LowDensityMessages-1890-20210608-22:32:31-29486                         1230.6
# LowDensityMessages-2020-20210608-22:37:17-30168                         1244.3
# LowDensityMessages-80-20210608-21:30:26-20689                           1118.6
# LowDensityMessages-210-20210608-21:34:36-21308                          1241.9
# LowDensityMessages-340-20210608-21:38:57-21905                          1244.7
# LowDensityMessages-470-20210608-21:43:18-22618                          1246.1
# LowDensityMessages-600-20210608-21:48:15-23348                          1035.7
# LowDensityMessages-730-20210608-21:52:45-23964                          1214.2
# LowDensityMessages-860-20210608-21:57:06-24561                          1246.4
# LowDensityMessages-990-20210608-22:01:30-25191                          1246.3
# LowDensityMessages-1120-20210608-22:06:06-25830                          996.0
# LowDensityMessages-1250-20210608-22:10:33-26440                         1177.0
# LowDensityMessages-1380-20210608-22:15:05-27063                         1240.1
# LowDensityMessages-1510-20210608-22:19:33-27701                         1246.7
# LowDensityMessages-1640-20210608-22:23:46-28284                          988.4
# LowDensityMessages-1770-20210608-22:28:23-28919                         1147.6
# LowDensityMessages-1900-20210608-22:33:00-29586                         1227.3
# LowDensityMessages-2030-20210608-22:37:26-30196                         1246.7
# LowDensityMessages-90-20210608-21:30:27-20693                           1115.3
# LowDensityMessages-220-20210608-21:34:37-21312                          1241.2
# LowDensityMessages-350-20210608-21:38:59-21915                          1243.4
# LowDensityMessages-480-20210608-21:44:15-22789                          1243.3
# LowDensityMessages-610-20210608-21:48:43-23407                          1027.6
# LowDensityMessages-740-20210608-21:52:48-23970                          1212.0
# LowDensityMessages-870-20210608-21:57:08-24567                          1247.9
# LowDensityMessages-1000-20210608-22:02:09-25284                         1247.2
# LowDensityMessages-1130-20210608-22:06:34-25888                          985.8
# LowDensityMessages-1260-20210608-22:10:50-26477                         1173.2
# LowDensityMessages-1390-20210608-22:15:09-27073                         1239.7
# LowDensityMessages-1520-20210608-22:19:47-27734                         1247.1
# LowDensityMessages-1650-20210608-22:24:28-28382                          957.9
# LowDensityMessages-1780-20210608-22:28:45-28967                         1156.8
# LowDensityMessages-1910-20210608-22:33:04-29598                         1230.4
# LowDensityMessages-2040-20210608-22:37:29-30213                         1248.3
# LowDensityMessages-100-20210608-21:30:27-20695                          1130.6
# LowDensityMessages-230-20210608-21:34:38-21316                          1244.9
# LowDensityMessages-360-20210608-21:39:58-22052                          1244.1
# LowDensityMessages-490-20210608-21:44:44-22855                          1243.5
# LowDensityMessages-620-20210608-21:48:44-23411                          1024.9
# LowDensityMessages-750-20210608-21:52:50-23976                          1207.9
# LowDensityMessages-880-20210608-21:57:49-24655                          1245.5
# LowDensityMessages-1010-20210608-22:02:38-25350                         1246.9
# LowDensityMessages-1140-20210608-22:06:53-25928                          955.4
# LowDensityMessages-1270-20210608-22:10:51-26481                         1168.2
# LowDensityMessages-1400-20210608-22:15:27-27129                         1241.1
# LowDensityMessages-1530-20210608-22:20:30-27836                         1247.1
# LowDensityMessages-1660-20210608-22:24:49-28427                          953.1
# LowDensityMessages-1790-20210608-22:28:47-28973                         1141.2
# LowDensityMessages-1920-20210608-22:33:09-29608                         1229.9
# LowDensityMessages-2050-20210608-22:38:16-30365                         1246.2
# LowDensityMessages-110-20210608-21:30:28-20699                          1116.9
# LowDensityMessages-240-20210608-21:35:37-21443                          1241.7
# LowDensityMessages-370-20210608-21:40:23-22104                          1244.1
# LowDensityMessages-500-20210608-21:44:44-22859                          1244.2
# LowDensityMessages-630-20210608-21:48:45-23415                          1000.4
# LowDensityMessages-760-20210608-21:53:30-24067                          1217.2
# LowDensityMessages-890-20210608-21:58:15-24719                          1246.1
# LowDensityMessages-1020-20210608-22:02:57-25397                         1247.0
# LowDensityMessages-1150-20210608-22:06:54-25932                          964.9
# LowDensityMessages-1280-20210608-22:11:11-26532                         1162.3
# LowDensityMessages-1410-20210608-22:16:10-27236                         1239.3
# LowDensityMessages-1540-20210608-22:20:52-27881                         1248.1
# LowDensityMessages-1670-20210608-22:24:52-28435                          952.9
# LowDensityMessages-1800-20210608-22:28:51-28984                         1145.2
# LowDensityMessages-1930-20210608-22:33:55-29711                         1227.0
# LowDensityMessages-2060-20210608-22:38:45-30457                         1245.4
# LowDensityMessages-120-20210608-21:31:43-20872                          1120.7
# LowDensityMessages-250-20210608-21:36:03-21507                          1242.6
# LowDensityMessages-380-20210608-21:40:25-22108                          1243.5
# LowDensityMessages-510-20210608-21:44:46-22865                          1243.2
# LowDensityMessages-640-20210608-21:49:28-23515                          1013.9
# LowDensityMessages-770-20210608-21:54:10-24161                          1211.3
# LowDensityMessages-900-20210608-21:58:33-24765                          1247.7
# LowDensityMessages-1030-20210608-22:02:58-25401                         1245.9
# LowDensityMessages-1160-20210608-22:07:15-25985                          956.1
# LowDensityMessages-1290-20210608-22:11:55-26628                         1164.7
# LowDensityMessages-1420-20210608-22:16:31-27280                         1237.3
# LowDensityMessages-1550-20210608-22:21:01-27909                         1248.2
# LowDensityMessages-1680-20210608-22:24:57-28454                          925.6
# LowDensityMessages-1810-20210608-22:29:44-29108                         1125.7
# LowDensityMessages-1940-20210608-22:34:24-29779                         1222.8
# LowDensityMessages-2070-20210608-22:38:54-30479                         1248.3
#
# qname                                            Floorplan.msgsPerSlot:sumVariance  \
# run
# LowDensityMessages-0-20210608-21:27:52-20225                            261.166667
# LowDensityMessages-130-20210608-21:31:44-20876                           87.066667
# LowDensityMessages-260-20210608-21:36:04-21511                           46.711111
# LowDensityMessages-390-20210608-21:40:27-22114                           73.288889
# LowDensityMessages-520-20210608-21:45:42-22989                          819.344444
# LowDensityMessages-650-20210608-21:49:55-23581                          182.177778
# LowDensityMessages-780-20210608-21:54:12-24167                       151800.011111
# LowDensityMessages-910-20210608-21:58:36-24772                           15.600000
# LowDensityMessages-1040-20210608-22:03:35-25479                         146.266667
# LowDensityMessages-1170-20210608-22:07:43-26044                         614.677778
# LowDensityMessages-1300-20210608-22:12:12-26666                         474.233333
# LowDensityMessages-1430-20210608-22:16:38-27297                         224.222222
# LowDensityMessages-1560-20210608-22:21:16-27944                         476.766667
# LowDensityMessages-1690-20210608-22:25:36-28536                          88.177778
# LowDensityMessages-1820-20210608-22:30:06-29163                         160.666667
# LowDensityMessages-1950-20210608-22:34:30-29791                         165.777778
# LowDensityMessages-10-20210608-21:27:52-20227                           166.900000
# LowDensityMessages-140-20210608-21:31:45-20880                           62.322222
# LowDensityMessages-270-20210608-21:36:05-21515                          118.488889
# LowDensityMessages-400-20210608-21:41:22-22237                           89.288889
# LowDensityMessages-530-20210608-21:46:11-23060                          143.111111
# LowDensityMessages-660-20210608-21:49:55-23583                           70.044444
# LowDensityMessages-790-20210608-21:54:14-24173                           20.622222
# LowDensityMessages-920-20210608-21:59:16-24863                           66.177778
# LowDensityMessages-1050-20210608-22:04:05-25551                         118.011111
# LowDensityMessages-1180-20210608-22:08:01-26093                         210.933333
# LowDensityMessages-1310-20210608-22:12:13-26670                          71.733333
# LowDensityMessages-1440-20210608-22:16:54-27331                         359.155556
# LowDensityMessages-1570-20210608-22:21:58-28040                         165.377778
# LowDensityMessages-1700-20210608-22:25:57-28591                          24.044444
# LowDensityMessages-1830-20210608-22:30:09-29171                          59.955556
# LowDensityMessages-1960-20210608-22:34:33-29801                          23.566667
# LowDensityMessages-20-20210608-21:27:52-20229                           296.277778
# LowDensityMessages-150-20210608-21:31:46-20884                           72.844444
# LowDensityMessages-280-20210608-21:37:03-21642                           32.233333
# LowDensityMessages-410-20210608-21:41:48-22295                           12.011111
# LowDensityMessages-540-20210608-21:46:12-23064                          307.066667
# LowDensityMessages-670-20210608-21:49:56-23589                           52.044444
# LowDensityMessages-800-20210608-21:54:55-24267                           46.677778
# LowDensityMessages-930-20210608-21:59:44-24926                           85.288889
# LowDensityMessages-1060-20210608-22:04:25-25594                         325.377778
# LowDensityMessages-1190-20210608-22:08:01-26097                         115.566667
# LowDensityMessages-1320-20210608-22:12:33-26715                          68.900000
# LowDensityMessages-1450-20210608-22:17:36-27427                          31.511111
# LowDensityMessages-1580-20210608-22:22:21-28091                         333.566667
# LowDensityMessages-1710-20210608-22:25:59-28597                         204.900000
# LowDensityMessages-1840-20210608-22:30:12-29179                          21.122222
# LowDensityMessages-1970-20210608-22:35:20-29905                          36.488889
# LowDensityMessages-30-20210608-21:27:52-20231                           132.711111
# LowDensityMessages-160-20210608-21:33:01-21089                       154329.111111
# LowDensityMessages-290-20210608-21:37:29-21695                           39.433333
# LowDensityMessages-420-20210608-21:41:51-22301                          307.600000
# LowDensityMessages-550-20210608-21:46:15-23072                          258.766667
# LowDensityMessages-680-20210608-21:50:40-23681                          137.066667
# LowDensityMessages-810-20210608-21:55:22-24325                           10.944444
# LowDensityMessages-940-20210608-22:00:02-24982                            5.333333
# LowDensityMessages-1070-20210608-22:04:26-25598                         105.155556
# LowDensityMessages-1200-20210608-22:08:24-26147                          99.555556
# LowDensityMessages-1330-20210608-22:13:16-26810                          16.400000
# LowDensityMessages-1460-20210608-22:17:58-27483                          60.000000
# LowDensityMessages-1590-20210608-22:22:28-28107                         175.433333
# LowDensityMessages-1720-20210608-22:26:04-28611                         127.733333
# LowDensityMessages-1850-20210608-22:31:03-29292                          94.666667
# LowDensityMessages-1980-20210608-22:35:50-29969                         141.377778
# LowDensityMessages-40-20210608-21:29:09-20510                           158.988889
# LowDensityMessages-170-20210608-21:33:10-21107                           27.733333
# LowDensityMessages-300-20210608-21:37:31-21701                            7.566667
# LowDensityMessages-430-20210608-21:41:52-22306                           18.544444
# LowDensityMessages-560-20210608-21:47:00-23171                          231.566667
# LowDensityMessages-690-20210608-21:51:20-23774                           88.266667
# LowDensityMessages-820-20210608-21:55:37-24356                           52.766667
# LowDensityMessages-950-20210608-22:00:03-24991                           25.877778
# LowDensityMessages-1080-20210608-22:04:53-25655                         184.844444
# LowDensityMessages-1210-20210608-22:09:09-26253                         128.322222
# LowDensityMessages-1340-20210608-22:13:37-26855                          10.500000
# LowDensityMessages-1470-20210608-22:18:05-27500                          17.344444
# LowDensityMessages-1600-20210608-22:22:32-28115                         610.677778
# LowDensityMessages-1730-20210608-22:27:00-28733                         213.566667
# LowDensityMessages-1860-20210608-22:31:34-29354                          22.177778
# LowDensityMessages-1990-20210608-22:35:58-29994                          13.344444
# LowDensityMessages-50-20210608-21:29:10-20514                           260.544444
# LowDensityMessages-180-20210608-21:33:11-21111                            4.266667
# LowDensityMessages-310-20210608-21:37:32-21705                           20.766667
# LowDensityMessages-440-20210608-21:42:48-22491                           17.377778
# LowDensityMessages-570-20210608-21:47:28-23231                          376.455556
# LowDensityMessages-700-20210608-21:51:22-23778                           57.788889
# LowDensityMessages-830-20210608-21:55:41-24366                            4.844444
# LowDensityMessages-960-20210608-22:00:42-25072                            2.844444
# LowDensityMessages-1090-20210608-22:05:22-25724                         512.177778
# LowDensityMessages-1220-20210608-22:09:26-26290                          63.211111
# LowDensityMessages-1350-20210608-22:13:41-26865                          27.733333
# LowDensityMessages-1480-20210608-22:18:19-27534                           2.177778
# LowDensityMessages-1610-20210608-22:23:15-28215                         267.433333
# LowDensityMessages-1740-20210608-22:27:22-28781                         204.322222
# LowDensityMessages-1870-20210608-22:31:36-29362                          20.711111
# LowDensityMessages-2000-20210608-22:36:00-30000                           4.900000
# LowDensityMessages-60-20210608-21:29:10-20517                           153.877778
# LowDensityMessages-190-20210608-21:33:11-21115                           21.211111
# LowDensityMessages-320-20210608-21:38:30-21840                            4.266667
# LowDensityMessages-450-20210608-21:43:16-22597                           13.288889
# LowDensityMessages-580-20210608-21:47:29-23233                          243.955556
# LowDensityMessages-710-20210608-21:51:24-23784                           44.933333
# LowDensityMessages-840-20210608-21:56:21-24461                            8.044444
# LowDensityMessages-970-20210608-22:01:11-25148                           14.277778
# LowDensityMessages-1100-20210608-22:05:41-25764                         518.666667
# LowDensityMessages-1230-20210608-22:09:27-26294                          61.788889
# LowDensityMessages-1360-20210608-22:14:00-26915                          13.788889
# LowDensityMessages-1490-20210608-22:19:03-27631                           1.788889
# LowDensityMessages-1620-20210608-22:23:37-28264                         399.822222
# LowDensityMessages-1750-20210608-22:27:23-28785                         258.933333
# LowDensityMessages-1880-20210608-22:31:41-29375                          20.844444
# LowDensityMessages-2010-20210608-22:36:48-30100                          24.044444
# LowDensityMessages-70-20210608-21:29:11-20519                           498.888889
# LowDensityMessages-200-20210608-21:34:11-21251                           23.822222
# LowDensityMessages-330-20210608-21:38:56-21901                           18.488889
# LowDensityMessages-460-20210608-21:43:17-22610                           11.211111
# LowDensityMessages-590-20210608-21:47:33-23243                          477.877778
# LowDensityMessages-720-20210608-21:52:05-23881                           80.766667
# LowDensityMessages-850-20210608-21:56:49-24519                            3.066667
# LowDensityMessages-980-20210608-22:01:29-25187                           10.044444
# LowDensityMessages-1110-20210608-22:05:42-25770                         583.155556
# LowDensityMessages-1240-20210608-22:09:48-26339                         114.455556
# LowDensityMessages-1370-20210608-22:14:44-27011                          12.500000
# LowDensityMessages-1500-20210608-22:19:25-27683                           1.788889
# LowDensityMessages-1630-20210608-22:23:43-28276                         535.788889
# LowDensityMessages-1760-20210608-22:27:28-28797                         316.622222
# LowDensityMessages-1890-20210608-22:32:31-29486                          46.711111
# LowDensityMessages-2020-20210608-22:37:17-30168                           7.122222
# LowDensityMessages-80-20210608-21:30:26-20689                           217.155556
# LowDensityMessages-210-20210608-21:34:36-21308                           54.988889
# LowDensityMessages-340-20210608-21:38:57-21905                            9.122222
# LowDensityMessages-470-20210608-21:43:18-22618                            1.433333
# LowDensityMessages-600-20210608-21:48:15-23348                          478.011111
# LowDensityMessages-730-20210608-21:52:45-23964                           47.066667
# LowDensityMessages-860-20210608-21:57:06-24561                            1.377778
# LowDensityMessages-990-20210608-22:01:30-25191                            2.455556
# LowDensityMessages-1120-20210608-22:06:06-25830                         272.666667
# LowDensityMessages-1250-20210608-22:10:33-26440                          62.444444
# LowDensityMessages-1380-20210608-22:15:05-27063                          15.211111
# LowDensityMessages-1510-20210608-22:19:33-27701                          16.677778
# LowDensityMessages-1640-20210608-22:23:46-28284                         574.044444
# LowDensityMessages-1770-20210608-22:28:23-28919                         347.822222
# LowDensityMessages-1900-20210608-22:33:00-29586                          67.344444
# LowDensityMessages-2030-20210608-22:37:26-30196                           6.677778
# LowDensityMessages-90-20210608-21:30:27-20693                           447.788889
# LowDensityMessages-220-20210608-21:34:37-21312                            4.844444
# LowDensityMessages-350-20210608-21:38:59-21915                           14.266667
# LowDensityMessages-480-20210608-21:44:15-22789                            2.900000
# LowDensityMessages-610-20210608-21:48:43-23407                          126.488889
# LowDensityMessages-740-20210608-21:52:48-23970                           61.777778
# LowDensityMessages-870-20210608-21:57:08-24567                            2.988889
# LowDensityMessages-1000-20210608-22:02:09-25284                           3.955556
# LowDensityMessages-1130-20210608-22:06:34-25888                         279.288889
# LowDensityMessages-1260-20210608-22:10:50-26477                         272.844444
# LowDensityMessages-1390-20210608-22:15:09-27073                           9.344444
# LowDensityMessages-1520-20210608-22:19:47-27734                           4.100000
# LowDensityMessages-1650-20210608-22:24:28-28382                         658.988889
# LowDensityMessages-1780-20210608-22:28:45-28967                         201.955556
# LowDensityMessages-1910-20210608-22:33:04-29598                          57.600000
# LowDensityMessages-2040-20210608-22:37:29-30213                           1.566667
# LowDensityMessages-100-20210608-21:30:27-20695                          268.488889
# LowDensityMessages-230-20210608-21:34:38-21316                           10.544444
# LowDensityMessages-360-20210608-21:39:58-22052                            5.211111
# LowDensityMessages-490-20210608-21:44:44-22855                           12.277778
# LowDensityMessages-620-20210608-21:48:44-23411                          666.766667
# LowDensityMessages-750-20210608-21:52:50-23976                          147.433333
# LowDensityMessages-880-20210608-21:57:49-24655                            4.277778
# LowDensityMessages-1010-20210608-22:02:38-25350                           2.322222
# LowDensityMessages-1140-20210608-22:06:53-25928                         306.266667
# LowDensityMessages-1270-20210608-22:10:51-26481                          84.622222
# LowDensityMessages-1400-20210608-22:15:27-27129                          21.877778
# LowDensityMessages-1530-20210608-22:20:30-27836                           4.322222
# LowDensityMessages-1660-20210608-22:24:49-28427                         942.766667
# LowDensityMessages-1790-20210608-22:28:47-28973                         321.288889
# LowDensityMessages-1920-20210608-22:33:09-29608                          36.322222
# LowDensityMessages-2050-20210608-22:38:16-30365                           9.066667
# LowDensityMessages-110-20210608-21:30:28-20699                          320.322222
# LowDensityMessages-240-20210608-21:35:37-21443                            8.900000
# LowDensityMessages-370-20210608-21:40:23-22104                            4.988889
# LowDensityMessages-500-20210608-21:44:44-22859                            9.288889
# LowDensityMessages-630-20210608-21:48:45-23415                          949.822222
# LowDensityMessages-760-20210608-21:53:30-24067                           95.288889
# LowDensityMessages-890-20210608-21:58:15-24719                            4.766667
# LowDensityMessages-1020-20210608-22:02:57-25397                           8.444444
# LowDensityMessages-1150-20210608-22:06:54-25932                         189.877778
# LowDensityMessages-1280-20210608-22:11:11-26532                         216.677778
# LowDensityMessages-1410-20210608-22:16:10-27236                          12.011111
# LowDensityMessages-1540-20210608-22:20:52-27881                           0.766667
# LowDensityMessages-1670-20210608-22:24:52-28435                         546.100000
# LowDensityMessages-1800-20210608-22:28:51-28984                         214.844444
# LowDensityMessages-1930-20210608-22:33:55-29711                          28.888889
# LowDensityMessages-2060-20210608-22:38:45-30457                           8.266667
# ...
# LowDensityMessages-10-20210608-21:27:52-20227                           9.241680
# LowDensityMessages-140-20210608-21:31:45-20880                          5.647344
# LowDensityMessages-270-20210608-21:36:05-21515                          7.786846
# LowDensityMessages-400-20210608-21:41:22-22237                          6.759608
# LowDensityMessages-530-20210608-21:46:11-23060                          8.557747
# LowDensityMessages-660-20210608-21:49:55-23583                          5.987005
# LowDensityMessages-790-20210608-21:54:14-24173                          3.248557
# LowDensityMessages-920-20210608-21:59:16-24863                          5.819409
# LowDensityMessages-1050-20210608-22:04:05-25551                         7.771131
# LowDensityMessages-1180-20210608-22:08:01-26093                        10.389518
# LowDensityMessages-1310-20210608-22:12:13-26670                         6.058753
# LowDensityMessages-1440-20210608-22:16:54-27331                        13.557015
# LowDensityMessages-1570-20210608-22:21:58-28040                         9.199439
# LowDensityMessages-1700-20210608-22:25:57-28591                         3.507762
# LowDensityMessages-1830-20210608-22:30:09-29171                         5.539078
# LowDensityMessages-1960-20210608-22:34:33-29801                         3.472737
# LowDensityMessages-20-20210608-21:27:52-20229                          12.313239
# LowDensityMessages-150-20210608-21:31:46-20884                          6.105497
# LowDensityMessages-280-20210608-21:37:03-21642                          4.061396
# LowDensityMessages-410-20210608-21:41:48-22295                          2.479216
# LowDensityMessages-540-20210608-21:46:12-23064                         12.535426
# LowDensityMessages-670-20210608-21:49:56-23589                          5.160716
# LowDensityMessages-800-20210608-21:54:55-24267                          4.887400
# LowDensityMessages-930-20210608-21:59:44-24926                          6.606463
# LowDensityMessages-1060-20210608-22:04:25-25594                        12.903773
# LowDensityMessages-1190-20210608-22:08:01-26097                         7.690225
# LowDensityMessages-1320-20210608-22:12:33-26715                         5.937893
# LowDensityMessages-1450-20210608-22:17:36-27427                         4.015639
# LowDensityMessages-1580-20210608-22:22:21-28091                        13.065141
# LowDensityMessages-1710-20210608-22:25:59-28597                        10.239854
# LowDensityMessages-1840-20210608-22:30:12-29179                         3.287703
# LowDensityMessages-1970-20210608-22:35:20-29905                         4.321187
# LowDensityMessages-30-20210608-21:27:52-20231                           8.240934
# LowDensityMessages-160-20210608-21:33:01-21089                        131.000000
# LowDensityMessages-290-20210608-21:37:29-21695                          4.492153
# LowDensityMessages-420-20210608-21:41:51-22301                         12.546308
# LowDensityMessages-550-20210608-21:46:15-23072                         11.507393
# LowDensityMessages-680-20210608-21:50:40-23681                          8.375075
# LowDensityMessages-810-20210608-21:55:22-24325                          2.366572
# LowDensityMessages-940-20210608-22:00:02-24982                          1.652046
# LowDensityMessages-1070-20210608-22:04:26-25598                         7.335655
# LowDensityMessages-1200-20210608-22:08:24-26147                         7.137655
# LowDensityMessages-1330-20210608-22:13:16-26810                         2.896975
# LowDensityMessages-1460-20210608-22:17:58-27483                         5.541131
# LowDensityMessages-1590-20210608-22:22:28-28107                         9.474992
# LowDensityMessages-1720-20210608-22:26:04-28611                         8.084905
# LowDensityMessages-1850-20210608-22:31:03-29292                         6.960194
# LowDensityMessages-1980-20210608-22:35:50-29969                         8.505764
# LowDensityMessages-40-20210608-21:29:09-20510                           9.019992
# LowDensityMessages-170-20210608-21:33:10-21107                          3.767245
# LowDensityMessages-300-20210608-21:37:31-21701                          1.967773
# LowDensityMessages-430-20210608-21:41:52-22306                          3.080560
# LowDensityMessages-560-20210608-21:47:00-23171                         10.885811
# LowDensityMessages-690-20210608-21:51:20-23774                          6.720803
# LowDensityMessages-820-20210608-21:55:37-24356                          5.196400
# LowDensityMessages-950-20210608-22:00:03-24991                          3.639035
# LowDensityMessages-1080-20210608-22:04:53-25655                         9.725814
# LowDensityMessages-1210-20210608-22:09:09-26253                         8.103520
# LowDensityMessages-1340-20210608-22:13:37-26855                         2.318021
# LowDensityMessages-1470-20210608-22:18:05-27500                         2.979223
# LowDensityMessages-1600-20210608-22:22:32-28115                        17.677825
# LowDensityMessages-1730-20210608-22:27:00-28733                        10.454169
# LowDensityMessages-1860-20210608-22:31:34-29354                         3.368851
# LowDensityMessages-1990-20210608-22:35:58-29994                         2.613202
# LowDensityMessages-50-20210608-21:29:10-20514                          11.546854
# LowDensityMessages-180-20210608-21:33:11-21111                          1.477635
# LowDensityMessages-310-20210608-21:37:32-21705                          3.259914
# LowDensityMessages-440-20210608-21:42:48-22491                          2.982084
# LowDensityMessages-570-20210608-21:47:28-23231                         13.879686
# LowDensityMessages-700-20210608-21:51:22-23778                          5.438072
# LowDensityMessages-830-20210608-21:55:41-24366                          1.574508
# LowDensityMessages-960-20210608-22:00:42-25072                          1.206484
# LowDensityMessages-1090-20210608-22:05:22-25724                        16.189489
# LowDensityMessages-1220-20210608-22:09:26-26290                         5.687475
# LowDensityMessages-1350-20210608-22:13:41-26865                         3.767245
# LowDensityMessages-1480-20210608-22:18:19-27534                         1.055673
# LowDensityMessages-1610-20210608-22:23:15-28215                        11.698510
# LowDensityMessages-1740-20210608-22:27:22-28781                        10.225406
# LowDensityMessages-1870-20210608-22:31:36-29362                         3.255551
# LowDensityMessages-2000-20210608-22:36:00-30000                         1.583510
# LowDensityMessages-60-20210608-21:29:10-20517                           8.873822
# LowDensityMessages-190-20210608-21:33:11-21115                          3.294614
# LowDensityMessages-320-20210608-21:38:30-21840                          1.477635
# LowDensityMessages-450-20210608-21:43:16-22597                          2.607757
# LowDensityMessages-580-20210608-21:47:29-23233                         11.173214
# LowDensityMessages-710-20210608-21:51:24-23784                          4.795204
# LowDensityMessages-840-20210608-21:56:21-24461                          2.028947
# LowDensityMessages-970-20210608-22:01:11-25148                          2.703044
# LowDensityMessages-1100-20210608-22:05:41-25764                        16.291720
# LowDensityMessages-1230-20210608-22:09:27-26294                         5.623128
# LowDensityMessages-1360-20210608-22:14:00-26915                         2.656363
# LowDensityMessages-1490-20210608-22:19:03-27631                         0.956785
# LowDensityMessages-1620-20210608-22:23:37-28264                        14.303958
# LowDensityMessages-1750-20210608-22:27:23-28785                        11.511098
# LowDensityMessages-1880-20210608-22:31:41-29375                         3.266013
# LowDensityMessages-2010-20210608-22:36:48-30100                         3.507762
# LowDensityMessages-70-20210608-21:29:11-20519                          15.978084
# LowDensityMessages-200-20210608-21:34:11-21251                          3.491515
# LowDensityMessages-330-20210608-21:38:56-21901                          3.075942
# LowDensityMessages-460-20210608-21:43:17-22610                          2.395229
# LowDensityMessages-590-20210608-21:47:33-23243                         15.637999
# LowDensityMessages-720-20210608-21:52:05-23881                          6.428932
# LowDensityMessages-850-20210608-21:56:49-24519                          1.252726
# LowDensityMessages-980-20210608-22:01:29-25187                          2.267179
# LowDensityMessages-1110-20210608-22:05:42-25770                        17.274878
# LowDensityMessages-1240-20210608-22:09:48-26339                         7.653167
# LowDensityMessages-1370-20210608-22:14:44-27011                         2.529169
# LowDensityMessages-1500-20210608-22:19:25-27683                         0.956785
# LowDensityMessages-1630-20210608-22:23:43-28276                        16.558448
# LowDensityMessages-1760-20210608-22:27:28-28797                        12.728976
# LowDensityMessages-1890-20210608-22:32:31-29486                         4.889144
# LowDensityMessages-2020-20210608-22:37:17-30168                         1.909108
# LowDensityMessages-80-20210608-21:30:26-20689                          10.541642
# LowDensityMessages-210-20210608-21:34:36-21308                          5.304693
# LowDensityMessages-340-20210608-21:38:57-21905                          2.160594
# LowDensityMessages-470-20210608-21:43:18-22618                          0.856439
# LowDensityMessages-600-20210608-21:48:15-23348                         15.640181
# LowDensityMessages-730-20210608-21:52:45-23964                          4.907717
# LowDensityMessages-860-20210608-21:57:06-24561                          0.839677
# LowDensityMessages-990-20210608-22:01:30-25191                          1.120979
# LowDensityMessages-1120-20210608-22:06:06-25830                        11.812418
# LowDensityMessages-1250-20210608-22:10:33-26440                         5.652879
# LowDensityMessages-1380-20210608-22:15:05-27063                         2.789994
# LowDensityMessages-1510-20210608-22:19:33-27701                         2.921406
# LowDensityMessages-1640-20210608-22:23:46-28284                        17.139397
# LowDensityMessages-1770-20210608-22:28:23-28919                        13.341401
# LowDensityMessages-1900-20210608-22:33:00-29586                         5.870481
# LowDensityMessages-2030-20210608-22:37:26-30196                         1.848582
# LowDensityMessages-90-20210608-21:30:27-20693                          15.137684
# LowDensityMessages-220-20210608-21:34:37-21312                          1.574508
# LowDensityMessages-350-20210608-21:38:59-21915                          2.701992
# LowDensityMessages-480-20210608-21:44:15-22789                          1.218209
# LowDensityMessages-610-20210608-21:48:43-23407                          8.045424
# LowDensityMessages-740-20210608-21:52:48-23970                          5.622622
# LowDensityMessages-870-20210608-21:57:08-24567                          1.236738
# LowDensityMessages-1000-20210608-22:02:09-25284                         1.422743
# LowDensityMessages-1130-20210608-22:06:34-25888                        11.955001
# LowDensityMessages-1260-20210608-22:10:50-26477                        11.816268
# LowDensityMessages-1390-20210608-22:15:09-27073                         2.186752
# LowDensityMessages-1520-20210608-22:19:47-27734                         1.448487
# LowDensityMessages-1650-20210608-22:24:28-28382                        18.363769
# LowDensityMessages-1780-20210608-22:28:45-28967                        10.166013
# LowDensityMessages-1910-20210608-22:33:04-29598                         5.429177
# LowDensityMessages-2040-20210608-22:37:29-30213                         0.895388
# LowDensityMessages-100-20210608-21:30:27-20695                         11.721574
# LowDensityMessages-230-20210608-21:34:38-21316                          2.322922
# LowDensityMessages-360-20210608-21:39:58-22052                          1.633007
# LowDensityMessages-490-20210608-21:44:44-22855                          2.506586
# LowDensityMessages-620-20210608-21:48:44-23411                         18.471821
# LowDensityMessages-750-20210608-21:52:50-23976                          8.686016
# LowDensityMessages-880-20210608-21:57:49-24655                          1.479558
# LowDensityMessages-1010-20210608-22:02:38-25350                         1.090121
# LowDensityMessages-1140-20210608-22:06:53-25928                        12.519086
# LowDensityMessages-1270-20210608-22:10:51-26481                         6.580592
# LowDensityMessages-1400-20210608-22:15:27-27129                         3.345988
# LowDensityMessages-1530-20210608-22:20:30-27836                         1.487224
# LowDensityMessages-1660-20210608-22:24:49-28427                        21.964680
# LowDensityMessages-1790-20210608-22:28:47-28973                        12.822439
# LowDensityMessages-1920-20210608-22:33:09-29608                         4.311307
# LowDensityMessages-2050-20210608-22:38:16-30365                         2.154004
# LowDensityMessages-110-20210608-21:30:28-20699                         12.803135
# LowDensityMessages-240-20210608-21:35:37-21443                          2.134115
# LowDensityMessages-370-20210608-21:40:23-22104                          1.597808
# LowDensityMessages-500-20210608-21:44:44-22859                          2.180242
# LowDensityMessages-630-20210608-21:48:45-23415                         22.046718
# LowDensityMessages-760-20210608-21:53:30-24067                          6.983030
# LowDensityMessages-890-20210608-21:58:15-24719                          1.561817
# LowDensityMessages-1020-20210608-22:02:57-25397                         2.078779
# LowDensityMessages-1150-20210608-22:06:54-25932                         9.857342
# LowDensityMessages-1280-20210608-22:11:11-26532                        10.530039
# LowDensityMessages-1410-20210608-22:16:10-27236                         2.479216
# LowDensityMessages-1540-20210608-22:20:52-27881                         0.626363
# LowDensityMessages-1670-20210608-22:24:52-28435                        16.717020
# LowDensityMessages-1800-20210608-22:28:51-28984                        10.485396
# LowDensityMessages-1930-20210608-22:33:55-29711                         3.844928
# LowDensityMessages-2060-20210608-22:38:45-30457                         2.056781
# LowDensityMessages-120-20210608-21:31:43-20872                         12.509318
# LowDensityMessages-250-20210608-21:36:03-21507                          3.149015
# LowDensityMessages-380-20210608-21:40:25-22108                          2.112693
# LowDensityMessages-510-20210608-21:44:46-22865                          2.206167
# LowDensityMessages-640-20210608-21:49:28-23515                         24.255300
# LowDensityMessages-770-20210608-21:54:10-24161                          5.841351
# LowDensityMessages-900-20210608-21:58:33-24765                          1.509989
# LowDensityMessages-1030-20210608-22:02:58-25401                         2.007819
# LowDensityMessages-1160-20210608-22:07:15-25985                        11.145955
# LowDensityMessages-1290-20210608-22:11:55-26628                         9.544349
# LowDensityMessages-1420-20210608-22:16:31-27280                         2.569317
# LowDensityMessages-1550-20210608-22:21:01-27909                         0.564281
# LowDensityMessages-1680-20210608-22:24:57-28454                        11.336896
# LowDensityMessages-1810-20210608-22:29:44-29108                         8.909632
# LowDensityMessages-1940-20210608-22:34:24-29779                         5.973694
# LowDensityMessages-2070-20210608-22:38:54-30479                         1.069054

# %%
for xFactor in factors:
    print('Plotting with', xFactor, 'on the x axis...')
    otherFactors = [fac for fac in factors if fac != xFactor]
    current = scalars_wide.sort_values([xFactor, *otherFactors])
    count = 0
    lastVal = None
    for index,row in current.iterrows():
        if lastVal != None and lastVal != row[xFactor]:
            count = 0
        current.loc[index, 'config'] = count
        count += 1
        lastVal = row[xFactor]
    x = current[xFactor].unique().tolist()
    for perfIndex, perfIndexDesc in perfIndexes:
        plt.figure(figsize=plotSize)
        plt.style.use(plotStyle)
        for cfg in range(0, int(current['config'].max()) + 1):
            y = current[current['config'] == cfg][perfIndex + 'Mean'].tolist()
            poserr = current[current['config'] == cfg][perfIndex + 'Poserr'].tolist()
            negerr = current[current['config'] == cfg][perfIndex + 'Negerr'].tolist()
            realy = []
            realx = []
            realne = []
            realpe = []
            curIdx = 0
            for val in y:
                if not math.isinf(val):
                    realy.append(val)
                    realx.append(x[curIdx])
                    realne.append(negerr[curIdx])
                    realpe.append(poserr[curIdx])
                curIdx += 1
            y = realy
            negerr = realne
            poserr = realpe
            err = [negerr, poserr]
            lbl = ""
            for fac in otherFactors:
                lbl += fac + '=' + str(current[current['config'] == cfg][fac].tolist()[0]) + ', '
            lbl = lbl[:-2]
            plt.errorbar(x=np.array(realx), y=np.array(y), yerr=np.array(err), capsize=3, linestyle='-', marker='.', markersize=10, label=lbl)
        plt.title('Full factorial plot for ' + perfIndexDesc)
        plt.ylabel(perfIndex)
        plt.xlabel(xFactor)
        plt.legend()
        if saveFigures:
            fig = plt.gcf()
            fig.savefig('figures/' + get_file_name(perfIndex) + '-' + xFactor + '-ffplot.png')
        plt.show()
    print('########################################')
    print()
# Out:
# Plotting with R on the x axis...
# ########################################
#
# Plotting with T on the x axis...
# ########################################
#
# Plotting with m on the x axis...
# ########################################

# %% [markdown]
# ## Observations
#
# Increase the broadcast radius is a way to decrease the total number of messages sent, specially if the maximum number of copies is low, but since we want to optimize the energy efficiency of the network, this is not a viable way.
# We get very great benefits reducing `m`, which provides also good benefits for energy efficiency.
# We can also increase `T`, which decreases messages (not so much) but we have to consider that this will increase so much the broadcast time.
#
# We get a very large variance in the experiments with `R=23m; T=3s; m=4` and `R=26m; T=2s; m=3`, probably because we find one experiment with very low coverage, caused probably by the random position of the users in the floor (we will study this in an other chapter)

# %% [markdown]
# ### Rerun this notebook
#
# To rerun this notebook, you can:
# - just rerun the simulations with the corresponding configuration: `./simulate.sh -s LowDensity -c LowDensityMessages -o messages` (you will get slighly different results)
# - download our datasets from `https://drive.google.com/file/d/1ZFRV2DecoTvax9lngEsuPPw8Cz1DXvLc/view?usp=sharing` (login with UNIPI institutional account)
# - use our seed to rerun the simulations. Add `seed-set = ${runnumber}21510` to the configuration
